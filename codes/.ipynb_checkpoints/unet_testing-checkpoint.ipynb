# %% [markdown]
# # U-Net testing

# %%
# !hostname
# Out:
# mtx37

# %%
import glob
import os
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, Conv2DTranspose, Reshape, concatenate, Dropout, Rescaling, LeakyReLU
import tensorflow.keras.layers as L
from tensorflow.keras.models import Model
from astropy.io import fits
import matplotlib.pyplot as plt
from gelsa import visu
from tqdm.notebook import tqdm
import tensorflow.keras.backend as K
# Out:
# 2025-12-05 22:30:16.481892: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-05 22:30:16.522988: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-05 22:30:16.523010: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-05 22:30:16.523016: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-05 22:30:16.529382: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Selecting GPU (0-4), if available

# %%
gpu=2
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.set_visible_devices(gpus[gpu], 'GPU')
    logical_gpus = tf.config.list_logical_devices('GPU')
    print("Using GPU number {}".format(gpu))
  except RuntimeError as e:
    print(e)
else:
    print("GPU not found")
# Out:
# GPU not found

# %%
print("TF version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU devices:", tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.14.0
# Built with CUDA: True
# GPU devices: []

# %% [markdown]
# ### Importing the data

# %%
folder_path = "/scratch/astro/nicolo.fiaba/training_sets_EL/"

# %%
hdu_rect = fits.open("/scratch/astro/nicolo.fiaba/training_sets_EL/labels_RGS000_0.fits", memmap=True)
hdu_rect_masked = fits.open("/scratch/astro/nicolo.fiaba/training_sets_EL/train_RGS000_0.fits", memmap=True)

# %%
img_data = np.array([hdu.data for hdu in hdu_rect[1:]])
img_data_masked = np.array([hdu.data for hdu in hdu_rect_masked[1:]])

# %%
""" Mask object: 
- 0: Existing pixel
- 1: Missing pixel
"""
mask = np.isnan(img_data_masked).astype(np.float32)

# %%
plt.imshow(mask[32], interpolation='nearest')

# %% [markdown]
# ### Setting a threshold to the flux value in each pixel:
# > Whenever a pixel exceeds the flux value of **16000**, its value is set back to **16000**

# %%
max_threshold = 16000 
"""
This was suggested by Savio. 
Ask again why, because looking at real data this doesn't seem to be the pixels maximum value. Anyway..
"""
img_data[img_data > max_threshold] = max_threshold
img_data_masked[img_data_masked > max_threshold] = max_threshold

# %% [markdown]
# ### Add gaussian noise to the spectra ($\sigma = \sqrt{800}$)

# %%
# Noise
sigma = np.sqrt(800)
size = (len(img_data), 512, 512)
noise = np.random.normal(loc=0, scale=sigma, size=size)

# %%
img_noise = img_data #+ noise (No noise on labels)
img_noise_masked = img_data_masked + noise

img_noise = np.array(img_noise, dtype=np.float32)
img_noise_masked = np.array(img_noise_masked, dtype=np.float32)

# %%
np.nanmax(img_noise_masked)
# Out:
# 16142.553

# %% [markdown]
# ### Rescaling images
#
# In ML it's crucial to renormalize the data in the (0, 1) range or (-1, 1).
#
# Everything is **rescaled** with the **same factor**, the maximum flux is the images with emission lines (since they are the brightest).
#
# **NB**: The mask dataset is already normalized [0, 1]

# %%
# Image normalization -> (0,1)
x_max = np.nanmax([img_noise, img_noise_masked])
x_min = np.nanmin([img_noise, img_noise_masked])

rescale = Rescaling(1./(x_max - x_min), offset=-x_min/(x_max - x_min), input_shape=(512, 512, 1))

# %%
img_noise = rescale(img_noise)
img_noise_masked = rescale(img_noise_masked)

# Converting to numpy, otherwise train_test_split function won't work
img_noise = img_noise.numpy()
img_noise_masked = img_noise_masked.numpy()

# %% [markdown]
# #### We stack the **masked images** and the **masks** themselves:
# These will be the inputs of the network: $(512, 512, 2)$

# %%
input_imgs = np.stack([img_noise_masked, mask], axis=-1)

# %% [markdown]
# ### Train and test set split

# %%
# test set is 10% of the whole dataset
x_train, x_test, y_train, y_test = train_test_split(
    input_imgs, img_noise, test_size=0.1, random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42)

x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
x_val = tf.convert_to_tensor(x_val, dtype=tf.float32)
x_test = tf.convert_to_tensor(x_test, dtype=tf.float32)

y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %%
# Set NaNs to 0 before feeding the U-Net
# NaNs are ONLY in the training images, not labels
x_train = tf.where(tf.math.is_nan(x_train), 0, x_train)
x_val = tf.where(tf.math.is_nan(x_val), 0, x_val)
x_test = tf.where(tf.math.is_nan(x_test), 0, x_test)

image_size = (x_train.shape[1], x_train.shape[2])

# %%
tf.reduce_max(x_train)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.0089096>

# %% [markdown]
# #### Now the lists are:
#
# - `x_train`, `x_test`, `x_val` : training, test and validation sets
# - `y_train`,`y_test`,`y_val` : training, test and validation sets of labels

# %%
print("Images in training set:", len(x_train),
      "\nImages in validation set:", len(x_val),
      "\nImages in test set:", len(x_test),
      "\nImage size:", image_size)
# Out:
# Images in training set: 3386
# Images in validation set: 847
# Images in test set: 471
# Image size: (512, 512)

# %%
BATCH_SIZE = 2

train_dataset = tf.data.Dataset.from_tensor_slices((x_train[:10], y_train[:10])).batch(BATCH_SIZE)#.shuffle(100)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val[:10], y_val[:10])).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test[:10], y_test[:10])).batch(BATCH_SIZE)

# %%
x_train.shape
# Out:
# TensorShape([3386, 512, 512, 2])

# %%
xlow, xhigh = 300, 500
ylow, yhigh = 300, 500

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
index = 456
plt.suptitle("RGS000, -4 tilt, close-up")
plt.subplot(121)
plt.xlim(xlow, xhigh)
plt.ylim(ylow, yhigh)
plt.imshow(x_train[index][...,0], origin='lower', aspect=1, vmin=0, vmax=0.03)
plt.title("Masked spectral image")

plt.subplot(122)
plt.imshow(y_train[index], origin='lower', aspect=1, vmin=0, vmax=0.03)
plt.xlim(xlow, xhigh)
plt.ylim(ylow, yhigh)
plt.title("Not masked - UNET targets")
# plt.savefig("EL_train_labels.png")
# Out:
# Text(0.5, 1.0, 'Not masked - UNET targets')

# %%
# w can easily become an hyperparameter to be optimized
def weighted_L2_loss(w):
    def loss(y_true, y_pred):
        error = K.square(y_true - y_pred)
        error = K.switch(K.less(y_true, tf.reduce_mean(train)), w * error, error)
        return error 
    return loss

def pow_downweight_loss(alpha):
    def loss(y_true, y_pred):
        y_true_clipped = K.clip(y_true, K.epsilon(), 1.0)
        y_pred_clipped = K.clip(y_pred, K.epsilon(), 1.0)

        y_true_rescaled = K.pow(y_true_clipped, alpha)
        y_pred_rescaled = K.pow(y_pred_clipped, alpha)

        error = K.square(y_true_rescaled - y_pred_rescaled)
        return error
    return K.mean(loss)

def log_downweight_loss(y_true, y_pred):
    
    y_true_rescaled = tf.math.log(1 + y_true)
    y_pred_rescaled = tf.math.log(1 + y_pred)

    error = K.square(y_true_rescaled - y_pred_rescaled)
    return K.mean(error)

def get_gradients(img):
    # img: (batch, H, W, 1)
    if len(img.shape) == 3:
        img = tf.expand_dims(img, axis=-1)  # add channel
    # horizontal gradient (dx)
    gx = tf.image.sobel_edges(img)[..., 0]
    # vertical gradient (dy)
    gy = tf.image.sobel_edges(img)[..., 1]

    return gx, gy

def gradient_loss(y_true, y_pred):
    gx_true, gy_true = get_gradients(y_true)
    gx_pred, gy_pred = get_gradients(y_pred)

    loss_gx = tf.reduce_mean(tf.abs(gx_true - gx_pred))
    loss_gy = tf.reduce_mean(tf.abs(gy_true - gy_pred))

    return loss_gx + loss_gy

def total_gradient_loss(y_true, y_pred):
    l1 = tf.reduce_mean(tf.abs(y_true - y_pred))
    g = gradient_loss(y_true, y_pred)

    return l1 + 0.2 * g 

def ssim_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # safety: ensure channel dimension is present
    if len(y_true.shape) == 3:
        y_true = tf.expand_dims(y_true, -1)
    if len(y_pred.shape) == 3:
        y_pred = tf.expand_dims(y_pred, -1)

    # compute 1 - SSIM
    return 1 - tf.image.ssim(
        y_true, y_pred,
        max_val=1.0,        # dynamic range
        filter_size=11      # your kernel size
    )

# %%
# Set hyerparameters
EPOCHS = 500
LEARNING_RATE = 1e-3
INIT_LR = 1e-3
MAX_LR = 1

# %% [markdown]
# ### Define the Neural Network

# %% [markdown]
# Architecture: [Image Inpainting Using AutoEncoder and Guided Selection of Predicted Pixels by Mohammad H. Givkashi](https://arxiv.org/pdf/2112.09262)

# %%
# Model 2: U-Net (usually used for Image Segmentation of Biomedical images)
# Define construction functions for fundamental blocks

def double_conv_block(x, n_filters):

    x = Conv2D(n_filters, 3, padding = "same", kernel_initializer = "he_normal")(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = Conv2D(n_filters, 3, padding = "same", kernel_initializer = "he_normal")(x)
    x = LeakyReLU(alpha=0.1)(x)

    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = MaxPool2D(2)(f)
    # p = Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    # 3: kernel size
    # 2: strides
    x = Conv2DTranspose(n_filters, 3, 2, padding='same')(x)
    x = concatenate([x, conv_features])
    # x = Dropout(0.3)(x)
    x = double_conv_block(x, n_filters)
    return x

# %%
# Define blocks for the Attention U-Net architecture (U-Net + Attention gates)

def conv_block(x, num_filters):
    x = L.Conv2D(num_filters, 3, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    x = L.Conv2D(num_filters, 3, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = L.MaxPool2D((2,2))(x)
    return x, p

def attention_gate(g, s, num_filters):
    Wg = L.Conv2D(num_filters, 1, padding='same')(g)
    Wg = L.BatchNormalization()(Wg)

    Ws = L.Conv2D(num_filters, 1, padding='same')(s)
    Ws = L.BatchNormalization()(Ws)

    out = L.Activation("relu")(Wg + Ws)
    out = L.Conv2D(num_filters, 1, padding='same')(out)
    out = L.Activation('sigmoid')(out)

    return out * s

def decoder_block(x, s, num_filters):
    x = L.UpSampling2D(interpolation='bilinear')(x)
    s = attention_gate(x, s, num_filters)
    x = L.Concatenate()([x, s])
    x = conv_block(x, num_filters)
    return x

# %%
# Build the U-Net model

def make_unet_model(image_size):
    inputs = Input(shape=(image_size[0], image_size[1], 1))

    # Encoder
    f1, p1 = downsample_block(inputs, 64)
    f2, p2 = downsample_block(p1, 128)
    f3, p3 = downsample_block(p2, 256)
    f4, p4 = downsample_block(p3, 512)
    
    # Bottleneck
    bottleneck = double_conv_block(p4, 1024)
    
    # Decoder
    u6 = upsample_block(bottleneck, f4, 512)
    u7 = upsample_block(u6, f3, 256)
    u8 = upsample_block(u7, f2, 128)
    u9 = upsample_block(u8, f1, 64)

    # Output
    outputs = Conv2D(1, 1, padding='same', activation='sigmoid')(u9)

    unet_model = Model(inputs, outputs, name='U-Net')

    return unet_model

# -----------------------------------------------------------------------

def attention_unet(image_size):
    """ Inputs """
    inputs = L.Input(shape=(image_size[0], image_size[1], 2))

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """ Bridge / Bottleneck """
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Outputs """
    outputs = L.Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    attention_unet_model = Model(inputs, outputs, name='Attention-UNET')
    return attention_unet_model

# %%
"""
unet_model = make_unet_model(image_size)

unet_model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate = 1),
                  # optimizer=optimizer,
                  loss='mse',
                  metrics=['mse'])

# unet_model.summary()
"""
# Out:
# "\nunet_model = make_unet_model(image_size)\n\nunet_model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate = 1),\n                  # optimizer=optimizer,\n                  loss='mse',\n                  metrics=['mse'])\n\n# unet_model.summary()\n"

# %%
attention_unet_model = attention_unet(image_size)

attention_unet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-3),
                  # optimizer=optimizer,
                  loss=total_gradient_loss,
                  metrics=['mae'])

# attention_unet_model.summary()

# %%
import os
checkpoint_path = "/scratch/astro/nicolo.fiaba/training_weights/unet_ckp.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 monitor='val_loss',
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=3,
                                           restore_best_weights=True,
                                           start_from_epoch=100)

def lr_schedule(epoch):
    if epoch < 250:
        return 2e-3
    elif epoch < 400:
        return 1e-4
    else:
    	return 1e-5

lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

# %% [markdown]
# ### Defining hyperparameters

# %%
print("Running for", EPOCHS, "epochs")
# Out:
# Running for 500 epochs

# %% [markdown]
# ### Training on GPU (`gpu03`)

# %%
hist = attention_unet_model.fit(
    train_dataset,
    epochs=EPOCHS,
    #batch_size=BATCH_SIZE,
    # shuffle=True,
    validation_data=val_dataset,
    callbacks=[lr_callback],
    verbose=2
)
# Out:
# Epoch 1/500
# 5/5 - 10s - loss: 0.4409 - mae: 0.3799 - val_loss: 1.0044 - val_mae: 0.9903 - lr: 0.0020 - 10s/epoch - 2s/step
# Epoch 2/500
# 5/5 - 1s - loss: 0.2011 - mae: 0.1807 - val_loss: 1.0044 - val_mae: 0.9903 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 3/500
# 5/5 - 1s - loss: 0.1267 - mae: 0.1133 - val_loss: 1.0044 - val_mae: 0.9903 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 4/500
# 5/5 - 1s - loss: 0.1046 - mae: 0.0926 - val_loss: 1.0044 - val_mae: 0.9903 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 5/500
# 5/5 - 1s - loss: 0.0790 - mae: 0.0699 - val_loss: 1.0044 - val_mae: 0.9903 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 6/500
# 5/5 - 1s - loss: 0.0670 - mae: 0.0580 - val_loss: 1.0044 - val_mae: 0.9899 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 7/500
# 5/5 - 1s - loss: 0.0574 - mae: 0.0490 - val_loss: 1.0035 - val_mae: 0.9873 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 8/500
# 5/5 - 1s - loss: 0.0484 - mae: 0.0407 - val_loss: 0.9873 - val_mae: 0.9643 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 9/500
# 5/5 - 1s - loss: 0.0439 - mae: 0.0364 - val_loss: 0.9514 - val_mae: 0.9252 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 10/500
# 5/5 - 1s - loss: 0.0379 - mae: 0.0307 - val_loss: 0.3993 - val_mae: 0.3682 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 11/500
# 5/5 - 1s - loss: 0.0323 - mae: 0.0259 - val_loss: 0.9074 - val_mae: 0.8698 - lr: 0.0020 - 1s/epoch - 203ms/step
# Epoch 12/500
# 5/5 - 1s - loss: 0.0314 - mae: 0.0243 - val_loss: 0.9521 - val_mae: 0.9200 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 13/500
# 5/5 - 1s - loss: 0.0302 - mae: 0.0236 - val_loss: 0.9435 - val_mae: 0.9162 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 14/500
# 5/5 - 1s - loss: 0.0280 - mae: 0.0213 - val_loss: 0.9381 - val_mae: 0.9082 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 15/500
# 5/5 - 1s - loss: 0.0251 - mae: 0.0190 - val_loss: 0.9151 - val_mae: 0.8875 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 16/500
# 5/5 - 1s - loss: 0.0234 - mae: 0.0176 - val_loss: 0.9153 - val_mae: 0.8931 - lr: 0.0020 - 1s/epoch - 203ms/step
# Epoch 17/500
# 5/5 - 1s - loss: 0.0216 - mae: 0.0159 - val_loss: 0.9209 - val_mae: 0.9004 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch 18/500
# 5/5 - 1s - loss: 0.0194 - mae: 0.0141 - val_loss: 0.9295 - val_mae: 0.9086 - lr: 0.0020 - 1s/epoch - 204ms/step
# Epoch
500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7360e-04 - val_loss: 0.0026 - val_mae: 9.7810e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 479/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7359e-04 - val_loss: 0.0026 - val_mae: 9.7793e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 480/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7356e-04 - val_loss: 0.0026 - val_mae: 9.7797e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 481/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7352e-04 - val_loss: 0.0026 - val_mae: 9.7788e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 482/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7350e-04 - val_loss: 0.0026 - val_mae: 9.7799e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 483/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7346e-04 - val_loss: 0.0026 - val_mae: 9.7796e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 484/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7343e-04 - val_loss: 0.0026 - val_mae: 9.7808e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 485/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7341e-04 - val_loss: 0.0026 - val_mae: 9.7815e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 486/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7338e-04 - val_loss: 0.0026 - val_mae: 9.7813e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 487/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7335e-04 - val_loss: 0.0026 - val_mae: 9.7795e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 488/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7333e-04 - val_loss: 0.0026 - val_mae: 9.7781e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 489/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7331e-04 - val_loss: 0.0026 - val_mae: 9.7797e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 490/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7328e-04 - val_loss: 0.0026 - val_mae: 9.7814e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 491/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7326e-04 - val_loss: 0.0026 - val_mae: 9.7809e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 492/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7322e-04 - val_loss: 0.0026 - val_mae: 9.7787e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 493/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7318e-04 - val_loss: 0.0026 - val_mae: 9.7803e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 494/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7316e-04 - val_loss: 0.0026 - val_mae: 9.7819e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 495/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7314e-04 - val_loss: 0.0026 - val_mae: 9.7846e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 496/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7311e-04 - val_loss: 0.0026 - val_mae: 9.7836e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 497/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7310e-04 - val_loss: 0.0026 - val_mae: 9.7864e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 498/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7307e-04 - val_loss: 0.0026 - val_mae: 9.7879e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 499/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7305e-04 - val_loss: 0.0026 - val_mae: 9.7844e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step
# Epoch 500/500
# 5/5 - 1s - loss: 0.0020 - mae: 7.7300e-04 - val_loss: 0.0026 - val_mae: 9.7851e-04 - lr: 1.0000e-05 - 1s/epoch - 204ms/step

# %%
plt.plot(hist.history['loss'], label='Loss')
plt.plot(hist.history['val_loss'], label='Validation loss')
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True, alpha=0.2)
plt.legend()
# plt.savefig("training_loss.png")

# %%
# attention_unet_model.save("/scratch/astro/nicolo.fiaba/trained_models/test_att_wrong.h5")

# %% [markdown]
# #### Saving the learning history

# %%
"""
import pickle
with open('/home/PERSONALE/nicolo.fiaba/trainHistoryDict', 'wb') as file_pi:
    pickle.dump(hist.history, file_pi)
"""

# %% [markdown]
# #### Loading the learning history

# %%
import pickle
with open('/scratch/astro/nicolo.fiaba/trained_models/EL_ATT_UNET_hist_RGS000_minus4', "rb") as file_pi:
    history = pickle.load(file_pi)

# %%
plt.plot(history['loss'][0:])
plt.plot(history['val_loss'][0:])
plt.yscale('log')

# %% [markdown]
# ### Loading trained model and evaluation

# %%
from keras.models import load_model
saved_model = load_model('/scratch/astro/nicolo.fiaba/trained_models/EL_attention_unet_model_RGS000_minus4.h5', compile=False)

saved_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss=total_gradient_loss,
                  metrics="mse")
# saved_model.summary()

# %% [markdown]
# ---

# %%
pred_trained = saved_model.predict(test_dataset)
pred_trained = np.squeeze(pred_trained)
# Out:
# 5/5 [==============================] - 1s 39ms/step

# %%
pred = attention_unet_model.predict(train_dataset)
pred = np.squeeze(pred)
# Out:
# 5/5 [==============================] - 0s 40ms/step

# %%
import random
index = 3
print(index)
from matplotlib.colors import ListedColormap

cmap = plt.cm.viridis
colors = cmap(np.arange(cmap.N))

colors[0] = [1, 1, 1, 1]

new_cmap = ListedColormap(colors)

fig, axs = plt.subplots(2, 3, figsize=(12,8))
# lis = [y_train[:10], pred]
lis = [y_train, x_train[...,0], pred]
titles = ['Label', 'Input', 'Output']

for i, ax in enumerate(axs.flatten()[:3]):
    ax.imshow(lis[i][index], aspect=1, vmin=0, vmax=0.1, origin='lower')
    ax.set_title(titles[i], fontsize=9)
    # ax.set_xlim(300, 400)
    # ax.set_ylim(170, 230)
for i, ax in enumerate(axs.flatten()[3:]):
    ax.imshow(lis[i][index], aspect=1, vmin=0, vmax=0.1, origin='lower')
    ax.set_title(titles[i]+' - zoomed in', fontsize=9)
    ax.set_xlim(300, 400)
    ax.set_ylim(100, 200)
plt.suptitle("Attention gate U-Net model - Test on RGS000, -4 tilt")
# plt.savefig("denoise_attUNET_testpred.png")
# Out:
# 3
# Text(0.5, 0.98, 'Attention gate U-Net model - Test on RGS000, -4 tilt')

# %%
tf.reduce_min(x_test[...,0])
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.009686017>

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.imshow(x_test[...,0][index] - pred_trained[index], aspect=1, vmin=0, vmax=0.01, origin='lower')
ax.set_xlim(300, 400)
ax.set_ylim(100, 200)
# Out:
# (100.0, 200.0)

# %%
flatten_diff = tf.reshape(y_test[...,0][index]-pred_trained[index], [-1])

# %%
plt.hist(flatten_diff, bins=np.linspace(-0.02, 0.02, 100));
plt.xlim(-0.025, 0.025)
# Out:
# (-0.025, 0.025)

# %% [markdown]
# #### Reconstruction error (*mse*)
#
# Let's compute the reconstruction error for each reconstructed image

# %%
indices = np.arange(len(img_data))
train_idx, test_idx = train_test_split(indices, test_size=0.1, random_state=42)
train_idx, val_idx = train_test_split(train_idx, test_size=0.2, random_state=42)

clean_train = img_data[train_idx]
clean_val = img_data[val_idx]
clean_test = img_data[test_idx]

clean_train = rescale(clean_train)
clean_val = rescale(clean_val)
clean_test = rescale(clean_test)

# %%
computed_mse = tf.reduce_mean(tf.keras.losses.MSE(test, pred_trained)).numpy()
expected_mse = tf.reduce_mean(tf.keras.losses.MSE(test, clean_test)).numpy()

print('Computed MSE:', computed_mse, "\nExpected MSE:", expected_mse)
# Out:
# Computed MSE: 4.98895e-05
# Expected MSE: 0.00029642938

# %%
index = 45
print(index)

fig, axs = plt.subplots(1, 3, figsize=(12,4))
lis = [test, clean_test, pred_trained]
titles = ['Input', 'Input \n without noise', 'Output']

for i, ax in enumerate(axs.flatten()):
    ax.imshow(visu.normalize_image(lis[i][index], levels=(5, 95)), aspect=1)
    ax.set_title(titles[i], fontsize=9)
    ax.set_xlim(50, 100)
    ax.set_ylim(50, 100)
plt.suptitle("Index: {}".format(index))
# Out:
# 45
# Text(0.5, 0.98, 'Index: 45')
