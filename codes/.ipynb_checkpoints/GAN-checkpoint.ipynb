# %% [markdown]
# ### Deep Convolutional Generative Adversarial Network (GAN)

# %% [markdown]
# The idea is to make the GAN learn on simulated 2D spectra (**GELSA**)
#
# The architecture of a GAN is **generator** + **discriminator**. We'll be implementing an *attention-gated U-Net* as generator.

# %%
import glob
import imageio
from IPython import display
import tensorflow as tf
import tensorflow.keras.layers as L
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
import time
import os
from tensorflow.keras.models import Model

# %%
# In each learning step we're passing multiple "batches" to the GAN. 
# The BATCH_SIZE defines the size of each batch, hence the number of batches
# BUFFER_SIZE must me >= number of images in the training set.

BUFFER_SIZE = 6000
BATCH_SIZE = 16

# %%
hdu_rect = fits.open("/scratch/astro/nicolo.fiaba/training_sets/labels_RGS180_4.fits", memmap=True)
hdu_rect_masked = fits.open("/scratch/astro/nicolo.fiaba/training_sets/train_RGS180_4.fits", memmap=True)

# %%
img_data = np.array([hdu.data for hdu in hdu_rect[1:]])
img_data_masked = np.array([hdu.data for hdu in hdu_rect_masked[1:]])

# %%
""" Mask object: 
- 0: Existing pixel
- 1: Missing pixel
"""
mask = np.isnan(img_data_masked).astype(np.float32)

# %% [markdown]
# #### Setting a threshold to the flux value in each pixel:
# > Whenever a pixel exceeds the flux value of 16000, its value is set back to 16000

# %%
max_threshold = 16000 
"""
This was suggested by Savio. 
Ask again why, because looking at real data this doesn't seem to be the pixels maximum value. Anyway..
"""
img_data[img_data > max_threshold] = max_threshold
img_data_masked[img_data_masked > max_threshold] = max_threshold

# %% [markdown]
# ### Add gaussian noise to the spectra ($\sigma = \sqrt{800}$)

# %%
# Noise
sigma = np.sqrt(800)
size = (len(img_data), 512, 512)
noise = np.random.normal(loc=0, scale=sigma, size=size)

# %%
img_noise = img_data + noise
img_noise_masked = img_data_masked + noise

img_noise = np.array(img_noise, dtype=np.float32)
img_noise_masked = np.array(img_noise_masked, dtype=np.float32)

# %% [markdown]
# ### Rescaling images
#
# In ML it's crucial to renormalize the data in the (0, 1) range or (-1, 1).
#
# Everything is **rescaled** with the **same factor**, the maximum flux is the images with emission lines (since they are the brightest).
#
# **NB**: The mask dataset is already normalized [0, 1]

# %%
# Image normalization -> (0,1)
x_max = np.nanmax(img_noise)
x_min = np.nanmin(img_noise)
rescale = L.Rescaling(1./(x_max - x_min), offset=-x_min/(x_max - x_min), input_shape=(512, 512, 1))

# %%
img_noise = rescale(img_noise)
img_noise_masked = rescale(img_noise_masked)

# Converting to numpy, otherwise train_test_split function won't work
img_noise = img_noise.numpy()
img_noise_masked = img_noise_masked.numpy()

# %% [markdown]
# #### We stack the **masked images** and the **masks** themselves:
# These will be the inputs of the network: $(512, 512, 2)$

# %%
input_imgs = np.stack([img_noise_masked, mask], axis=-1)

# %% [markdown]
# ### Train and test set split

# %%
from sklearn.model_selection import train_test_split

# test set is 10% of the whole dataset
x_train, x_test, y_train, y_test = train_test_split(
    img_noise_masked, img_noise, test_size=0.1, random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42)

x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
x_val = tf.convert_to_tensor(x_val, dtype=tf.float32)
x_test = tf.convert_to_tensor(x_test, dtype=tf.float32)

y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %%
# Set NaNs to 0 before feeding the U-Net
x_train = tf.where(tf.math.is_nan(x_train), 0., x_train)
x_val = tf.where(tf.math.is_nan(x_val), 0., x_val)
x_test = tf.where(tf.math.is_nan(x_test), 0., x_test)

image_size = (x_train.shape[1], x_train.shape[2])

# %%
print("Images in training set:", len(x_train),
      "\nImages in validation set:", len(x_val),
      "\nImages in test set:", len(x_test),
      "\nImage size:", image_size)
# Out:
# Images in training set: 3386
# Images in validation set: 847
# Images in test set: 471
# Image size: (512, 512)

# %%
BATCH_SIZE = 2

train_dataset = tf.data.Dataset.from_tensor_slices((x_train[:10], y_train[:10])).batch(BATCH_SIZE)#.shuffle(100)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val[:10], y_val[:10])).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test[:10], y_test[:10])).batch(BATCH_SIZE)

# %% [markdown]
# ---

# %% [markdown]
# Let's try to train a GAN to inpaint Euclid-like 2D spectra

# %% [markdown]
# ### Build the generator (Attention-gated U-Net)

# %%
# Necessary blocks for the attention-gated UNET

def conv_block(x, num_filters):
    x = L.Conv2D(num_filters, 3, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    x = L.Conv2D(num_filters, 3, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = L.MaxPool2D((2,2))(x)
    return x, p

def attention_gate(g, s, num_filters):
    Wg = L.Conv2D(num_filters, 1, padding='same')(g)
    Wg = L.BatchNormalization()(Wg)

    Ws = L.Conv2D(num_filters, 1, padding='same')(s)
    Ws = L.BatchNormalization()(Ws)

    out = L.Activation("relu")(Wg + Ws)
    out = L.Conv2D(num_filters, 1, padding='same')(out)
    out = L.Activation('sigmoid')(out)

    return out * s

def decoder_block(x, s, num_filters):
    x = L.UpSampling2D(interpolation='bilinear')(x)
    s = attention_gate(x, s, num_filters)
    x = L.Concatenate()([x, s])
    x = conv_block(x, num_filters)
    return x

# %%
# Autoencoder used as a generator for the inpainting task

def build_generator(image_size):
    """ Inputs """
    inputs = L.Input(shape=(image_size[0], image_size[1], 1))

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """ Bridge / Bottleneck """
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Outputs """
    outputs = L.Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    attention_unet_model = Model(inputs, outputs, name='Attention-UNET')
    return attention_unet_model

# %%
generator = build_generator(image_size)

# %% [markdown]
# Trick to go back to the original (10, 500) shape

# %% [markdown]
# ### Build the discriminator

# %%
# Conv2D is "downscaling" the image
# This is just a simple "binary classifier"
def build_discriminator():
    inputs = L.Input(shape=(image_size[0], image_size[1], 1))
    x = L.Conv2D(64, 3, strides=2, padding='same')(inputs)
    x = L.LeakyReLU(0.2)(x)

    x = L.Conv2D(128, 3, strides=2, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.LeakyReLU(0.2)(x)

    x = L.Conv2D(256, 3, strides=2, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.LeakyReLU(0.2)(x)

    x = L.Conv2D(512, 3, strides=2, padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.LeakyReLU(0.2)(x)

    x = L.Flatten()(x)
    outputs = L.Dense(1, activation='sigmoid')(x)

    discriminator = Model(inputs, outputs, name='Discriminator')

    return discriminator

# %%
discriminator = build_discriminator()

# %%
discriminator.summary()
# Out:
# Model: "Discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 512, 512, 1)]     0
#
#  conv2d_140 (Conv2D)         (None, 256, 256, 64)      640
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 256, 256, 64)      0
#
#  conv2d_141 (Conv2D)         (None, 128, 128, 128)     73856
#
#  batch_normalization_116 (B  (None, 128, 128, 128)     512
#  atchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 128, 128, 128)     0
#
#  conv2d_142 (Conv2D)         (None, 64, 64, 256)       295168
#
#  batch_normalization_117 (B  (None, 64, 64, 256)       1024
#  atchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 64, 64, 256)       0
#
#  conv2d_143 (Conv2D)         (None, 32, 32, 512)       1180160
#
#  batch_normalization_118 (B  (None, 32, 32, 512)       2048
#  atchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 32, 32, 512)       0
#
#  flatten_4 (Flatten)         (None, 524288)            0
#
#  dense_4 (Dense)             (None, 1)                 524289
#
# =================================================================
# Total params: 2077697 (7.93 MB)
# Trainable params: 2075905 (7.92 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %% [markdown]
# We need to train the GAN: training the generator and discriminator side by side.
#
# We can't use the **.fit** method. We need to write our own training loop (step)

# %% [markdown]
# ### Training loop

# %% [markdown]
# We need a custom loss function for the GAN: One for the generator, one for the discriminator

# %%
# Optimizer
from tensorflow.keras.optimizers import Adam
# Loss function
from tensorflow.keras.losses import BinaryCrossentropy, MeanAbsoluteError

# %% [markdown]
# We'll be basically rewarding the generator for tricking the discriminator and rewarding the discriminator for determining the correct type of image: fake (reconstructed) or real (original)

# %%
# g for generator
g_opt = Adam(learning_rate=0.0001)
# d for discriminator
d_opt = Adam(learning_rate=0.00001) # NB

g_loss = MeanAbsoluteError()
d_loss = BinaryCrossentropy()

# %% [markdown]
# #### We now need to build a subclassed model
#
# The idea is to modify the original class and change the **.fit** method as we wish.

# %%
# Importing the base model class to subclass our training step
from tensorflow.keras.models import Model

# %%
class FashionGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # Here we're inheriting args and kwargs from base class (Keras Model)
        super().__init__(*args, **kwargs) 

        # Create attributes for gen and discr
        self.generator = generator
        self.discriminator = discriminator
  
    def compile(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs):
        super().compile(*args, **kwargs)

        # Create attributes for losses and optimizers
        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss

    # train_step takes a batch of data
    def train_step(self, data): # this is called when you call the .fit method
        # Get data
        original_images, masked_images = data
        reconstructed_images = self.generator(masked_images, training=False)

        # Train the discriminator
        # We need to calculate the gradient
        with tf.GradientTape() as d_tape:
            # Pass the original and reconstructred images to discriminator
            yhat_origin = self.discriminator(original_images, training=True)
            yhat_recons = self.discriminator(reconstructed_images, training=True)
            yhat_orcons = tf.concat([yhat_origin, yhat_recons], axis=0)
            
            # Create labels for orig and reconst imgs (TRUE labels)
            y_orcons = tf.concat([tf.zeros_like(yhat_origin), tf.ones_like(yhat_recons)], axis=0)
            
            # Add noise to the TRUE outputs
            noise_origin = 0.15*tf.random.uniform(tf.shape(yhat_origin))
            noise_recons = -0.15*tf.random.uniform(tf.shape(yhat_recons))
            y_orcons += tf.concat([noise_origin, noise_recons], axis=0)
            
            # Calculate loss
            total_d_loss = self.d_loss(y_orcons, yhat_orcons)
            
        # Apply backprop: outside the "with" loop. First we calculate the gradient, then apply that using optimizers
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables)
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables)) # d_opt is Adam optimizer

        # Train the generator
        with tf.GradientTape() as g_tape:
            # Generate reconstructed images
            gen_images = self.generator(masked_images, training=True)
            
            # Create predicted labels
            predicted_labels = self.discriminator(gen_images, training=False)
            
            # Calculate loss
            # We're implying that generated images are REAL and we reward the generator for faking out the discriminator
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels)
            
        # Apply backpropagation
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        mae = tf.reduce_mean(tf.abs(tf.expand_dims(original_images, -1) - reconstructed_images))

        return {"d_loss": total_d_loss, "g_loss": total_g_loss, "recon_mae": mae}

# %%
# Create instance of subclassed model
fashgan = FashionGAN(generator, discriminator)

# %%
# Compile the model
fashgan.compile(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# #### Build Callback

# %%
from tensorflow.keras.callbacks import Callback

# %% [markdown]
# Skip for now
#
# ---

# %%
hist = fashgan.fit(train_dataset, epochs=200)
# Out:
# Epoch 1/200
# 2025-11-18 11:36:27.976753: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] remapper failed: INVALID_ARGUMENT: Mutation::Apply error: fanout 'gradient_tape/Discriminator/leaky_re_lu_16/LeakyRelu/LeakyReluGrad' exist for missing node 'Discriminator/conv2d_140/BiasAdd'.
# 5/5 [==============================] - 19s 3s/step - d_loss: 0.4598 - g_loss: 0.4942 - recon_mae: 0.6372
# Epoch 2/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.4574 - g_loss: 0.4782 - recon_mae: 0.3383
# Epoch 3/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.6708 - g_loss: 0.4829 - recon_mae: 0.1720
# Epoch 4/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.4596 - g_loss: 0.5100 - recon_mae: 0.1262
# Epoch 5/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.6986 - g_loss: 0.5347 - recon_mae: 0.1023
# Epoch 6/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.6683 - g_loss: 0.5694 - recon_mae: 0.1776
# Epoch 7/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.5045 - g_loss: 0.5840 - recon_mae: 0.1623
# Epoch 8/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.4055 - g_loss: 0.5707 - recon_mae: 0.1909
# Epoch 9/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2972 - g_loss: 0.5695 - recon_mae: 0.1625
# Epoch 10/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.4288 - g_loss: 0.5622 - recon_mae: 0.1068
# Epoch 11/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3311 - g_loss: 0.5459 - recon_mae: 0.3393
# Epoch 12/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3899 - g_loss: 0.5208 - recon_mae: 0.3935
# Epoch 13/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3553 - g_loss: 0.4837 - recon_mae: 0.4076
# Epoch 14/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3171 - g_loss: 0.4470 - recon_mae: 0.4169
# Epoch 15/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3482 - g_loss: 0.4160 - recon_mae: 0.4413
# Epoch 16/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3015 - g_loss: 0.3889 - recon_mae: 0.4509
# Epoch 17/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3040 - g_loss: 0.3937 - recon_mae: 0.3802
# Epoch 18/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2810 - g_loss: 0.3805 - recon_mae: 0.3738
# Epoch 19/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2426 - g_loss: 0.3406 - recon_mae: 0.2982
# Epoch 20/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2756 - g_loss: 0.2972 - recon_mae: 0.2373
# Epoch 21/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2987 - g_loss: 0.3065 - recon_mae: 0.2753
# Epoch 22/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3562 - g_loss: 0.3379 - recon_mae: 0.3101
# Epoch 23/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2706 - g_loss: 0.2909 - recon_mae: 0.2209
# Epoch 24/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3057 - g_loss: 0.2293 - recon_mae: 0.2833
# Epoch 25/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2456 - g_loss: 0.1864 - recon_mae: 0.3911
# Epoch 26/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2932 - g_loss: 0.2084 - recon_mae: 0.2778
# Epoch 27/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2256 - g_loss: 0.2439 - recon_mae: 0.3367
# Epoch 28/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2808 - g_loss: 0.2093 - recon_mae: 0.3791
# Epoch 29/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2848 - g_loss: 0.1427 - recon_mae: 0.4476
# Epoch 30/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2825 - g_loss: 0.1233 - recon_mae: 0.4358
# Epoch 31/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2812 - g_loss: 0.1472 - recon_mae: 0.4812
# Epoch 32/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3087 - g_loss: 0.0938 - recon_mae: 0.5837
# Epoch 33/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2981 - g_loss: 0.0574 - recon_mae: 0.5821
# Epoch 34/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2731 - g_loss: 0.0876 - recon_mae: 0.5375
# Epoch 35/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3299 - g_loss: 0.1003 - recon_mae: 0.5617
# Epoch 36/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2829 - g_loss: 0.0617 - recon_mae: 0.5646
# Epoch 37/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3078 - g_loss: 0.0414 - recon_mae: 0.5498
# Epoch 38/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2868 - g_loss: 0.0287 - recon_mae: 0.4994
# Epoch 39/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2714 - g_loss: 0.0241 - recon_mae: 0.5057
# Epoch 40/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2443 - g_loss: 0.0142 - recon_mae: 0.4847
# Epoch 41/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2542 - g_loss: 0.0124 - recon_mae: 0.4878
# Epoch 42/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2522 - g_loss: 0.0088 - recon_mae: 0.5010
# Epoch 43/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2334 - g_loss: 0.0067 - recon_mae: 0.4615
# Epoch 44/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2410 - g_loss: 0.0072 - recon_mae: 0.4546
# Epoch 45/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2906 - g_loss: 0.0045 - recon_mae: 0.4578
# Epoch 46/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2791 - g_loss: 0.0024 - recon_mae: 0.4744
# Epoch 47/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2201 - g_loss: 0.0022 - recon_mae: 0.4718
# Epoch 48/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2608 - g_loss: 0.0016 - recon_mae: 0.4583
# Epoch 49/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2586 - g_loss: 7.8132e-04 - recon_mae: 0.4611
# Epoch 50/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3081 - g_loss: 3.6507e-04 - recon_mae: 0.4745
# Epoch 51/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2707 - g_loss: 3.6521e-04 - recon_mae: 0.4881
# Epoch 52/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2827 - g_loss: 3.1149e-04 - recon_mae: 0.4982
# Epoch 53/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3045 - g_loss: 1.4049e-04 - recon_mae: 0.5053
# Epoch 54/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2778 - g_loss: 1.1229e-04 - recon_mae: 0.5124
# Epoch 55/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2849 - g_loss: 2.1825e-04 - recon_mae: 0.5197
# Epoch 56/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2504 - g_loss: 1.7474e-04 - recon_mae: 0.5257
# Epoch 57/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2437 - g_loss: 8.9035e-05 - recon_mae: 0.5305
# Epoch 58/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2884 - g_loss: 1.0023e-04 - recon_mae: 0.5349
# Epoch 59/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2829 - g_loss: 7.8275e-05 - recon_mae: 0.5388
# Epoch 60/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2423 - g_loss: 4.8960e-05 - recon_mae: 0.5428
# Epoch 61/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3390 - g_loss: 7.5979e-05 - recon_mae: 0.5471
# Epoch 62/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2955 - g_loss: 4.9090e-05 - recon_mae: 0.5514
# Epoch 63/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2815 - g_loss: 1.7533e-05 - recon_mae: 0.5559
# Epoch 64/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2750 - g_loss: 2.5333e-05 - recon_mae: 0.5606
# Epoch 65/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2735 - g_loss: 5.0992e-05 - recon_mae: 0.5650
# Epoch 66/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3179 - g_loss: 3.1022e-05 - recon_mae: 0.5692
# Epoch 67/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2820 - g_loss: 1.3587e-05 - recon_mae: 0.5733
# Epoch 68/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2561 - g_loss: 4.4813e-05 - recon_mae: 0.5770
# Epoch 69/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.1969 - g_loss: 9.3231e-05 - recon_mae: 0.5799
# Epoch 70/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3233 - g_loss: 5.8926e-05 - recon_mae: 0.5822
# Epoch 71/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2650 - g_loss: 3.5476e-05 - recon_mae: 0.5847
# Epoch 72/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2907 - g_loss: 1.8744e-04 - recon_mae: 0.5862
# Epoch 73/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2863 - g_loss: 6.6262e-05 - recon_mae: 0.5856
# Epoch 74/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2830 - g_loss: 5.4086e-05 - recon_mae: 0.5859
# Epoch 75/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2750 - g_loss: 7.0087e-05 - recon_mae: 0.5869
# Epoch 76/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2990 - g_loss: 5.0943e-05 - recon_mae: 0.5880
# Epoch 77/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2762 - g_loss: 1.3997e-04 - recon_mae: 0.5886
# Epoch 78/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3195 - g_loss: 7.8577e-05 - recon_mae: 0.5869
# Epoch 79/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2597 - g_loss: 6.0173e-05 - recon_mae: 0.5860
# Epoch 80/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2613 - g_loss: 2.4317e-04 - recon_mae: 0.5859
# Epoch 81/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2858 - g_loss: 1.0389e-04 - recon_mae: 0.5827
# Epoch 82/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3156 - g_loss: 7.9408e-05 - recon_mae: 0.5824
# Epoch 83/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2737 - g_loss: 8.6433e-05 - recon_mae: 0.5842
# Epoch 84/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3324 - g_loss: 9.7809e-05 - recon_mae: 0.5864
# Epoch 85/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2464 - g_loss: 8.2211e-05 - recon_mae: 0.5881
# Epoch 86/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2709 - g_loss: 3.8334e-04 - recon_mae: 0.5883
# Epoch 87/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3259 - g_loss: 4.8131e-04 - recon_mae: 0.5871
# Epoch 88/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3296 - g_loss: 8.2699e-05 - recon_mae: 0.5849
# Epoch 89/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3030 - g_loss: 3.2735e-04 - recon_mae: 0.5842
# Epoch 90/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3270 - g_loss: 2.6028e-04 - recon_mae: 0.5820
# Epoch 91/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2969 - g_loss: 1.1800e-04 - recon_mae: 0.5799
# Epoch 92/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2201 - g_loss: 3.9171e-04 - recon_mae: 0.5799
# Epoch 93/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2657 - g_loss: 0.0020 - recon_mae: 0.5790
# Epoch 94/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2719 - g_loss: 0.0011 - recon_mae: 0.5619
# Epoch 95/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2510 - g_loss: 9.0914e-04 - recon_mae: 0.5514
# Epoch 96/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2685 - g_loss: 0.0017 - recon_mae: 0.5263
# Epoch 97/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2934 - g_loss: 0.0010 - recon_mae: 0.5325
# Epoch 98/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3064 - g_loss: 0.0142 - recon_mae: 0.4635
# Epoch 99/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3647 - g_loss: 0.8811 - recon_mae: 0.2911
# Epoch 100/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3263 - g_loss: 0.9890 - recon_mae: 0.3275
# Epoch 101/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3198 - g_loss: 0.8406 - recon_mae: 0.3774
# Epoch 102/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3044 - g_loss: 0.2425 - recon_mae: 0.4724
# Epoch 103/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2467 - g_loss: 0.0581 - recon_mae: 0.5349
# Epoch 104/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.4077 - g_loss: 0.0341 - recon_mae: 0.5352
# Epoch 105/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3097 - g_loss: 0.0297 - recon_mae: 0.5196
# Epoch 106/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2917 - g_loss: 0.0484 - recon_mae: 0.5062
# Epoch 107/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3009 - g_loss: 0.0286 - recon_mae: 0.4908
# Epoch 108/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2550 - g_loss: 0.0359 - recon_mae: 0.4530
# Epoch 109/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2854 - g_loss: 0.1191 - recon_mae: 0.3693
# Epoch 110/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2895 - g_loss: 0.2873 - recon_mae: 0.3482
# Epoch 111/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3141 - g_loss: 0.3058 - recon_mae: 0.3639
# Epoch 112/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3104 - g_loss: 0.3018 - recon_mae: 0.2593
# Epoch 113/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2603 - g_loss: 0.4578 - recon_mae: 0.3359
# Epoch 114/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2927 - g_loss: 0.4035 - recon_mae: 0.3297
# Epoch 115/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2689 - g_loss: 0.3152 - recon_mae: 0.2196
# Epoch 116/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2448 - g_loss: 0.4676 - recon_mae: 0.2040
# Epoch 117/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3593 - g_loss: 0.2918 - recon_mae: 0.1916
# Epoch 118/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3306 - g_loss: 0.2579 - recon_mae: 0.1874
# Epoch 119/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2636 - g_loss: 0.5310 - recon_mae: 0.1949
# Epoch 120/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2621 - g_loss: 0.2645 - recon_mae: 0.2067
# Epoch 121/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3333 - g_loss: 0.4841 - recon_mae: 0.2259
# Epoch 122/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3139 - g_loss: 0.5863 - recon_mae: 0.2572
# Epoch 123/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3385 - g_loss: 0.3584 - recon_mae: 0.2920
# Epoch 124/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3304 - g_loss: 0.2716 - recon_mae: 0.1942
# Epoch 125/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2917 - g_loss: 0.3103 - recon_mae: 0.1944
# Epoch 126/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3056 - g_loss: 0.3550 - recon_mae: 0.1993
# Epoch 127/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2656 - g_loss: 0.3382 - recon_mae: 0.2008
# Epoch 128/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3097 - g_loss: 0.2567 - recon_mae: 0.1651
# Epoch 129/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3217 - g_loss: 0.2373 - recon_mae: 0.2296
# Epoch 130/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2789 - g_loss: 0.1755 - recon_mae: 0.1880
# Epoch 131/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3230 - g_loss: 0.2665 - recon_mae: 0.2509
# Epoch 132/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2793 - g_loss: 0.2184 - recon_mae: 0.1662
# Epoch 133/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3021 - g_loss: 0.1442 - recon_mae: 0.2087
# Epoch 134/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2469 - g_loss: 0.1177 - recon_mae: 0.1562
# Epoch 135/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2553 - g_loss: 0.1553 - recon_mae: 0.1339
# Epoch 136/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2620 - g_loss: 0.1759 - recon_mae: 0.1350
# Epoch 137/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2880 - g_loss: 0.0787 - recon_mae: 0.1608
# Epoch 138/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2652 - g_loss: 0.0781 - recon_mae: 0.1913
# Epoch 139/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2543 - g_loss: 0.0531 - recon_mae: 0.1619
# Epoch 140/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.3092 - g_loss: 0.0947 - recon_mae: 0.1401
# Epoch 141/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2671 - g_loss: 0.0371 - recon_mae: 0.1376
# Epoch 142/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2943 - g_loss: 0.0183 - recon_mae: 0.1403
# Epoch 143/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2992 - g_loss: 0.0170 - recon_mae: 0.1365
# Epoch 144/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2691 - g_loss: 0.0186 - recon_mae: 0.1438
# Epoch 145/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2921 - g_loss: 0.0073 - recon_mae: 0.1624
# Epoch 146/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2526 - g_loss: 0.0063 - recon_mae: 0.1678
# Epoch 147/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2927 - g_loss: 0.0043 - recon_mae: 0.1620
# Epoch 148/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2840 - g_loss: 0.0030 - recon_mae: 0.1555
# Epoch 149/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2768 - g_loss: 0.0028 - recon_mae: 0.1522
# Epoch 150/200
# 5/5 [==============================] - 14s 3s/step - d_loss: 0.2879 - g_loss: 0.0013 - recon_mae: 0.1521
# Epoch 151/200
# 2/5 [===========>..................] - ETA: 8s - d_loss: 0.3137 - g_loss: 0.0010 - recon_mae: 0.1570

# %%
plt.suptitle("Loss")
plt.plot(hist.history['d_loss'], label='d_loss')
plt.plot(hist.history['g_loss'], label='g_loss')
plt.yscale('log')
plt.legend()
plt.show()

# %%
img_predicted = generator.predict(train_dataset)
# Out:
# 5/5 [==============================] - 3s 678ms/step

# %%
img_predicted.shape
# Out:
# (10, 512, 512, 1)

# %%
from gelsa import visu

plt.figure(figsize=(10,3))
plt.imshow(visu.normalize_image(img_predicted[1], levels=(5, 95)), aspect=1)
