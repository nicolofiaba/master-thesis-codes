# %%
# !hostname
# Out:
# gpu03

# %% [markdown]
# ## Neural Network testing
# #### Trained with `UNet.py`

# %%
import matplotlib.image as mpimg

# %%
import glob
import os
import numpy as np

# Path to your folder
path = "/home/PERSONALE/nicolo.fiaba/.cache/kagglehub/datasets/aryankaushik005/pixart/versions/1/PixART dataset/automobile"

# Get all JPG image paths
image_files = glob.glob(os.path.join(path, "*.jpg"))

# Read and store all images in a list
images = [mpimg.imread(img_path) for img_path in image_files]

# Convert to numpy array (optional, for training)
images = np.array(images, dtype=np.float32)

print("Loaded images:", len(images))
print("Shape of one image:", images[0].shape)
# Out:
# Loaded images: 200
# Shape of one image: (512, 512, 3)

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, Conv2DTranspose, Reshape, concatenate, Dropout, Rescaling, LeakyReLU
from keras.models import Model
from astropy.io import fits
import matplotlib.pyplot as plt
from gelsa import visu
from tqdm.notebook import tqdm
# Out:
# 2025-11-04 21:03:58.232821: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-04 21:03:58.262876: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-04 21:03:58.262899: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-04 21:03:58.262905: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-04 21:03:58.268252: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.set_visible_devices(gpus[2], 'GPU')
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    print(e)
# Out:
# 2025-11-04 21:04:02.119843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78570 MB memory:  -> device: 2, name: H100 80GB HBM3, pci bus id: 0000:cb:00.0, compute capability: 9.0

# %%
print("TF version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU devices:", tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.14.0
# Built with CUDA: True
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %% [markdown]
# ### Train and test set split

# %%
# test set is 10% of the whole dataset
x_train, x_test, y_train, y_test = train_test_split(
    images, images, test_size=0.1, random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ### Rescaling images
#
# In ML it's crucial to renormalize the data in the (0, 1) range or (-1, 1).
#
# Everything is **rescaled** with the **same factor**, the maximum flux is the images with emission lines (since they are the brightest).
#
# **NB**: The mask dataset is already normalized [0, 1]

# %%
# rescale = Rescaling(1./(x_max - x_min), offset=-x_min/(x_max - x_min), input_shape=(512, 512, 1))
rescale = Rescaling(1./255, input_shape=(512, 512, 3))

# %%
train = rescale(y_train)
val = rescale(y_val)
test = rescale(y_test)

# %%
# train = y_train.astype(np.float32) / 255.0
# val   = y_val.astype(np.float32)   / 255.0
# test  = y_test.astype(np.float32)  / 255.0

# %%
# w can easily become an hyperparameter to be optimized
def weighted_L2_loss(w):
    def loss(y_true, y_pred):
        error = K.square(y_true - y_pred)
        error = K.switch(K.less(y_true, tf.reduce_mean(train)), w * error, error)
        return error 
    return loss

def pow_downweight_loss(alpha):
    def loss(y_true, y_pred):
        y_true_clipped = K.clip(y_true, K.epsilon(), 1.0)
        y_pred_clipped = K.clip(y_pred, K.epsilon(), 1.0)

        y_true_rescaled = K.pow(y_true_clipped, alpha)
        y_pred_rescaled = K.pow(y_pred_clipped, alpha)

        error = K.square(y_true_rescaled - y_pred_rescaled)
        return error
    return K.mean(loss)

def log_downweight_loss(y_true, y_pred):
    
    y_true_rescaled = tf.math.log(1 + y_true)
    y_pred_rescaled = tf.math.log(1 + y_pred)

    error = K.square(y_true_rescaled - y_pred_rescaled)
    return K.mean(error)

# %%
image_size = (train.shape[1], train.shape[2])
print("Images in training set:", len(train), 
      "\nImages in validation set:", len(val), 
      "\nImages in test set:", len(test), 
      "\nImage size:", image_size)
# Out:
# Images in training set: 144
# Images in validation set: 36
# Images in test set: 20
# Image size: (512, 512)

# %% [markdown]
# ### Define the Neural Network

# %% [markdown]
# Architecture: [Image Inpainting Using AutoEncoder and Guided Selection of Predicted Pixels by Mohammad H. Givkashi](https://arxiv.org/pdf/2112.09262)

# %%
# Model 2: U-Net (usually used for Image Segmentation of Biomedical images)
# Define construction functions for fundamental blocks

def double_conv_block(x, n_filters):

    x = Conv2D(n_filters, 3, padding = "same", kernel_initializer = "he_normal")(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = Conv2D(n_filters, 3, padding = "same", kernel_initializer = "he_normal")(x)
    x = LeakyReLU(alpha=0.1)(x)

    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = MaxPool2D(2)(f)
    # p = Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    # 3: kernel size
    # 2: strides
    x = Conv2DTranspose(n_filters, 3, 2, padding='same')(x)
    x = concatenate([x, conv_features])
    # x = Dropout(0.3)(x)
    x = double_conv_block(x, n_filters)
    return x

# %%
# Build the U-Net model

def make_unet_model(image_size):
    inputs = Input(shape=(image_size[0], image_size[1], 3))

    # Encoder
    f1, p1 = downsample_block(inputs, 64)
    f2, p2 = downsample_block(p1, 128)
    f3, p3 = downsample_block(p2, 256)
    f4, p4 = downsample_block(p3, 512)
    
    # Bottleneck
    bottleneck = double_conv_block(p4, 1024)
    
    # Decoder
    u6 = upsample_block(bottleneck, f4, 512)
    u7 = upsample_block(u6, f3, 256)
    u8 = upsample_block(u7, f2, 128)
    u9 = upsample_block(u8, f1, 64)

    # Output
    outputs = Conv2D(3, 1, padding='same', activation='sigmoid')(u9)

    unet_model = Model(inputs, outputs, name='U-Net')

    return unet_model

# %%
unet_model = make_unet_model(image_size)

unet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss='mse',
                  metrics=['mse'])

# unet_model.summary()

# %%
import os
checkpoint_path = "/scratch/astro/nicolo.fiaba/training_weights/unet_ckp.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 monitor='val_loss',
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=3,
                                           restore_best_weights=True,
                                           start_from_epoch=100)

# %% [markdown]
# ### Defining hyperparameters

# %%
# Set hyerparameters
EPOCHS = 500
BATCH_SIZE = 16
LEARNING_RATE = 1e-4

# %%
print("Running for", EPOCHS, "epochs")
# Out:
# Running for 500 epochs

# %% [markdown]
# ### Training on GPU (`gpu03`)

# %%
# autoencoder_2 = make_autoencoder_model_2(image_size)

hist = unet_model.fit(
    train[:4], train[:4],
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    validation_data=(val[:4], val[:4]),
    # callbacks=[cp_callback],
    verbose=2
)
# autoencoder_2.evaluate(test_mask)
# Out:
# Epoch 1/500
# 1/1 - 0s - loss: 0.1131 - mse: 0.1131 - val_loss: 0.0890 - val_mse: 0.0890 - 490ms/epoch - 490ms/step
# Epoch 2/500
# 1/1 - 0s - loss: 0.1073 - mse: 0.1073 - val_loss: 0.0852 - val_mse: 0.0852 - 281ms/epoch - 281ms/step
# Epoch 3/500
# 1/1 - 0s - loss: 0.1022 - mse: 0.1022 - val_loss: 0.0848 - val_mse: 0.0848 - 282ms/epoch - 282ms/step
# Epoch 4/500
# 1/1 - 0s - loss: 0.0982 - mse: 0.0982 - val_loss: 0.0825 - val_mse: 0.0825 - 280ms/epoch - 280ms/step
# Epoch 5/500
# 1/1 - 0s - loss: 0.0930 - mse: 0.0930 - val_loss: 0.0727 - val_mse: 0.0727 - 278ms/epoch - 278ms/step
# Epoch 6/500
# 1/1 - 0s - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0661 - val_mse: 0.0661 - 278ms/epoch - 278ms/step
# Epoch 7/500
# 1/1 - 0s - loss: 0.0778 - mse: 0.0778 - val_loss: 0.0656 - val_mse: 0.0656 - 279ms/epoch - 279ms/step
# Epoch 8/500
# 1/1 - 0s - loss: 0.0722 - mse: 0.0722 - val_loss: 0.0551 - val_mse: 0.0551 - 278ms/epoch - 278ms/step
# Epoch 9/500
# 1/1 - 0s - loss: 0.0661 - mse: 0.0661 - val_loss: 0.0493 - val_mse: 0.0493 - 279ms/epoch - 279ms/step
# Epoch 10/500
# 1/1 - 0s - loss: 0.0577 - mse: 0.0577 - val_loss: 0.0590 - val_mse: 0.0590 - 280ms/epoch - 280ms/step
# Epoch 11/500
# 1/1 - 0s - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0457 - val_mse: 0.0457 - 279ms/epoch - 279ms/step
# Epoch 12/500
# 1/1 - 0s - loss: 0.0539 - mse: 0.0539 - val_loss: 0.0449 - val_mse: 0.0449 - 280ms/epoch - 280ms/step
# Epoch 13/500
# 1/1 - 0s - loss: 0.0526 - mse: 0.0526 - val_loss: 0.0422 - val_mse: 0.0422 - 278ms/epoch - 278ms/step
# Epoch 14/500
# 1/1 - 0s - loss: 0.0461 - mse: 0.0461 - val_loss: 0.0445 - val_mse: 0.0445 - 280ms/epoch - 280ms/step
# Epoch 15/500
# 1/1 - 0s - loss: 0.0467 - mse: 0.0467 - val_loss: 0.0375 - val_mse: 0.0375 - 279ms/epoch - 279ms/step
# Epoch 16/500
# 1/1 - 0s - loss: 0.0429 - mse: 0.0429 - val_loss: 0.0379 - val_mse: 0.0379 - 278ms/epoch - 278ms/step
# Epoch 17/500
# 1/1 - 0s - loss: 0.0431 - mse: 0.0431 - val_loss: 0.0361 - val_mse: 0.0361 - 278ms/epoch - 278ms/step
# Epoch 18/500
# 1/1 - 0s - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0409 - val_mse: 0.0409 - 279ms/epoch - 279ms/step
# Epoch 19/500
# 1/1 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0332 - val_mse: 0.0332 - 281ms/epoch - 281ms/step
# Epoch 20/500
# 1/1 - 0s - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0339 - val_mse: 0.0339 - 279ms/epoch - 279ms/step
# Epoch 21/500
# 1/1 - 0s - loss: 0.0377 - mse: 0.0377 - val_loss: 0.0318 - val_mse: 0.0318 - 279ms/epoch - 279ms/step
# Epoch 22/500
# 1/1 - 0s - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0382 - val_mse: 0.0382 - 278ms/epoch - 278ms/step
# Epoch 23/500
# 1/1 - 0s - loss: 0.0360 - mse: 0.0360 - val_loss: 0.0293 - val_mse: 0.0293 - 278ms/epoch - 278ms/step
# Epoch 24/500
# 1/1 - 0s - loss: 0.0314 - mse: 0.0314 - val_loss: 0.0301 - val_mse: 0.0301 - 279ms/epoch - 279ms/step
# Epoch 25/500
# 1/1 - 0s - loss: 0.0327 - mse: 0.0327 - val_loss: 0.0281 - val_mse: 0.0281 - 279ms/epoch - 279ms/step
# Epoch 26/500
# 1/1 - 0s - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0346 - val_mse: 0.0346 - 279ms/epoch - 279ms/step
# Epoch 27/500
# 1/1 - 0s - loss: 0.0312 - mse: 0.0312 - val_loss: 0.0265 - val_mse: 0.0265 - 278ms/epoch - 278ms/step
# Epoch 28/500
# 1/1 - 0s - loss: 0.0267 - mse: 0.0267 - val_loss: 0.0269 - val_mse: 0.0269 - 279ms/epoch - 279ms/step
# Epoch 29/500
# 1/1 - 0s - loss: 0.0279 - mse: 0.0279 - val_loss: 0.0256 - val_mse: 0.0256 - 278ms/epoch - 278ms/step
# Epoch 30/500
# 1/1 - 0s - loss: 0.0243 - mse: 0.0243 - val_loss: 0.0313 - val_mse: 0.0313 - 279ms/epoch - 279ms/step
# Epoch 31/500
# 1/1 - 0s - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0246 - val_mse: 0.0246 - 279ms/epoch - 279ms/step
# Epoch 32/500
# 1/1 - 0s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0248 - val_mse: 0.0248 - 278ms/epoch - 278ms/step
# Epoch 33/500
# 1/1 - 0s - loss: 0.0230 - mse: 0.0230 - val_loss: 0.0242 - val_mse: 0.0242 - 280ms/epoch - 280ms/step
# Epoch 34/500
# 1/1 - 0s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0283 - val_mse: 0.0283 - 278ms/epoch - 278ms/step
# Epoch 35/500
# 1/1 - 0s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0230 - val_mse: 0.0230 - 278ms/epoch - 278ms/step
# Epoch 36/500
# 1/1 - 0s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0231 - val_mse: 0.0231 - 280ms/epoch - 280ms/step
# Epoch 37/500
# 1/1 - 0s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0238 - val_mse: 0.0238 - 280ms/epoch - 280ms/step
# Epoch 38/500
# 1/1 - 0s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0246 - val_mse: 0.0246 - 279ms/epoch - 279ms/step
# Epoch 39/500
# 1/1 - 0s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0224 - val_mse: 0.0224 - 280ms/epoch - 280ms/step
# Epoch 40/500
# 1/1 - 0s - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0221 - val_mse: 0.0221 - 278ms/epoch - 278ms/step
# Epoch 41/500
# 1/1 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0252 - val_mse: 0.0252 - 279ms/epoch - 279ms/step
# Epoch 42/500
# 1/1 - 0s - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0213 - val_mse: 0.0213 - 280ms/epoch - 280ms/step
# Epoch 43/500
# 1/1 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0209 - val_mse: 0.0209 - 279ms/epoch - 279ms/step
# Epoch 44/500
# 1/1 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0218 - val_mse: 0.0218 - 277ms/epoch - 277ms/step
# Epoch 45/500
# 1/1 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0202 - val_mse: 0.0202 - 278ms/epoch - 278ms/step
# Epoch 46/500
# 1/1 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0196 - val_mse: 0.0196 - 278ms/epoch - 278ms/step
# Epoch 47/500
# 1/1 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0207 - val_mse: 0.0207 - 278ms/epoch - 278ms/step
# Epoch 48/500
# 1/1 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0183 - val_mse: 0.0183 - 279ms/epoch - 279ms/step
# Epoch 49/500
# 1/1 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0185 - val_mse: 0.0185 - 279ms/epoch - 279ms/step
# Epoch 50/500
# 1/1 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0175 - val_mse: 0.0175 - 278ms/epoch - 278ms/step
# Epoch 51/500
# 1/1 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0179 - val_mse: 0.0179 - 280ms/epoch - 280ms/step
# Epoch 52/500
# 1/1 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0173 - val_mse: 0.0173 - 279ms/epoch - 279ms/step
# Epoch 53/500
# 1/1 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0184 - val_mse: 0.0184 - 279ms/epoch - 279ms/step
# Epoch 54/500
# 1/1 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0179 - val_mse: 0.0179 - 280ms/epoch - 280ms/step
# Epoch 55/500
# 1/1 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0285 - val_mse: 0.0285 - 278ms/epoch - 278ms/step
# Epoch 56/500
# 1/1 - 0s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0332 - val_mse: 0.0332 - 278ms/epoch - 278ms/step
# Epoch 57/500
# 1/1 - 0s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0255 - val_mse: 0.0255 - 278ms/epoch - 278ms/step
# Epoch 58/500
# 1/1 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0433 - val_mse: 0.0433 - 279ms/epoch - 279ms/step
# Epoch 59/500
# 1/1 - 0s - loss: 0.0288 - mse: 0.0288 - val_loss: 0.0239 - val_mse: 0.0239 - 279ms/epoch - 279ms/step
# Epoch 60/500
# 1/1 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0279 - val_mse: 0.0279 - 280ms/epoch - 280ms/step
# Epoch 61/500
# 1/1 - 0s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0245 - val_mse: 0.0245 - 278ms/epoch - 278ms/step
# Epoch 62/500
# 1/1 - 0s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0253 - val_mse: 0.0253 - 279ms/epoch - 279ms/step
# Epoch 63/500
# 1/1 - 0s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0252 - val_mse: 0.0252 - 280ms/epoch - 280ms/step
# Epoch 64/500
# 1/1 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0192 - val_mse: 0.0192 - 279ms/epoch - 279ms/step
# Epoch 65/500
# 1/1 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0204 - val_mse: 0.0204 - 278ms/epoch - 278ms/step
# Epoch 66/500
# 1/1 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0211 - val_mse: 0.0211 - 280ms/epoch - 280ms/step
# Epoch 67/500
# 1/1 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0203 - val_mse: 0.0203 - 279ms/epoch - 279ms/step
# Epoch 68/500
# 1/1 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0175 - val_mse: 0.0175 - 278ms/epoch - 278ms/step
# Epoch 69/500
# 1/1 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0178 - val_mse: 0.0178 - 279ms/epoch - 279ms/step
# Epoch 70/500
# 1/1 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0194 - val_mse: 0.0194 - 279ms/epoch - 279ms/step
# Epoch 71/500
# 1/1 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0180 - val_mse: 0.0180 - 280ms/epoch - 280ms/step
# Epoch 72/500
# 1/1 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0177 - val_mse: 0.0177 - 278ms/epoch - 278ms/step
# Epoch 73/500
# 1/1 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0175 - val_mse: 0.0175 - 279ms/epoch - 279ms/step
# Epoch 74/500
# 1/1 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0189 - val_mse: 0.0189 - 280ms/epoch - 280ms/step
# Epoch 75/500
# 1/1 - 0s - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0177 - val_mse: 0.0177 - 279ms/epoch - 279ms/step
# Epoch 76/500
# 1/1 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0177 - val_mse: 0.0177 - 278ms/epoch - 278ms/step
# Epoch 77/500
# 1/1 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0177 - val_mse: 0.0177 - 278ms/epoch - 278ms/step
# Epoch 78/500
# 1/1 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0182 - val_mse: 0.0182 - 279ms/epoch - 279ms/step
# Epoch 79/500
# 1/1 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0180 - val_mse: 0.0180 - 278ms/epoch - 278ms/step
# Epoch 80/500
# 1/1 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0165 - val_mse: 0.0165 - 279ms/epoch - 279ms/step
# Epoch 81/500
# 1/1 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0163 - val_mse: 0.0163 - 280ms/epoch - 280ms/step
# Epoch 82/500
# 1/1 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0168 - val_mse: 0.0168 - 281ms/epoch - 281ms/step
# Epoch 83/500
# 1/1 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0160 - val_mse: 0.0160 - 280ms/epoch - 280ms/step
# Epoch 84/500
# 1/1 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0148 - val_mse: 0.0148 - 280ms/epoch - 280ms/step
# Epoch 85/500
# 1/1 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0146 - val_mse: 0.0146 - 278ms/epoch - 278ms/step
# Epoch 86/500
# 1/1 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0148 - val_mse: 0.0148 - 277ms/epoch - 277ms/step
# Epoch 87/500
# 1/1 - 0s - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0141 - val_mse: 0.0141 - 278ms/epoch - 278ms/step
# Epoch 88/500
# 1/1 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0137 - val_mse: 0.0137 - 279ms/epoch - 279ms/step
# Epoch 89/500
# 1/1 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0141 - val_mse: 0.0141 - 280ms/epoch - 280ms/step
# Epoch 90/500
# 1/1 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0138 - val_mse: 0.0138 - 280ms/epoch - 280ms/step
# Epoch 91/500
# 1/1 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0135 - val_mse: 0.0135 - 280ms/epoch - 280ms/step
# Epoch 92/500
# 1/1 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0133 - val_mse: 0.0133 - 280ms/epoch - 280ms/step
# Epoch 93/500
# 1/1 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0133 - val_mse: 0.0133 - 280ms/epoch - 280ms/step
# Epoch 94/500
# 1/1 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0130 - val_mse: 0.0130 - 278ms/epoch - 278ms/step
# Epoch 95/500
# 1/1 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0127 - val_mse: 0.0127 - 279ms/epoch - 279ms/step
# Epoch 96/500
# 1/1 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0128 - val_mse: 0.0128 - 280ms/epoch - 280ms/step
# Epoch 97/500
# 1/1 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0123 - val_mse: 0.0123 - 279ms/epoch - 279ms/step
# Epoch 98/500
# 1/1 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0121 - val_mse: 0.0121 - 280ms/epoch - 280ms/step
# Epoch 99/500
# 1/1 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0122 - val_mse: 0.0122 - 280ms/epoch - 280ms/step
# Epoch 100/500
# 1/1 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0117 - val_mse: 0.0117 - 280ms/epoch - 280ms/step
# Epoch 101/500
# 1/1 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0116 - val_mse: 0.0116 - 279ms/epoch - 279ms/step
# Epoch 102/500
# 1/1 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0115 - val_mse: 0.0115 - 280ms/epoch - 280ms/step
# Epoch 103/500
# 1/1 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0113 - val_mse: 0.0113 - 278ms/epoch - 278ms/step
# Epoch 104/500
# 1/1 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0114 - val_mse: 0.0114 - 278ms/epoch - 278ms/step
# Epoch 105/500
# 1/1 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0112 - val_mse: 0.0112 - 278ms/epoch - 278ms/step
# Epoch 106/500
# 1/1 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0112 - val_mse: 0.0112 - 279ms/epoch - 279ms/step
# Epoch 107/500
# 1/1 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0110 - val_mse: 0.0110 - 279ms/epoch - 279ms/step
# Epoch 108/500
# 1/1 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0108 - val_mse: 0.0108 - 278ms/epoch - 278ms/step
# Epoch 109/500
# 1/1 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0106 - val_mse: 0.0106 - 280ms/epoch - 280ms/step
# Epoch 110/500
# 1/1 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0105 - val_mse: 0.0105 - 279ms/epoch - 279ms/step
# Epoch 111/500
# 1/1 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0105 - val_mse: 0.0105 - 281ms/epoch - 281ms/step
# Epoch 112/500
# 1/1 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0109 - val_mse: 0.0109 - 278ms/epoch - 278ms/step
# Epoch 113/500
# 1/1 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0112 - val_mse: 0.0112 - 278ms/epoch - 278ms/step
# Epoch 114/500
# 1/1 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0134 - val_mse: 0.0134 - 280ms/epoch - 280ms/step
# Epoch 115/500
# 1/1 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0121 - val_mse: 0.0121 - 280ms/epoch - 280ms/step
# Epoch 116/500
# 1/1 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0129 - val_mse: 0.0129 - 278ms/epoch - 278ms/step
# Epoch 117/500
# 1/1 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0108 - val_mse: 0.0108 - 279ms/epoch - 279ms/step
# Epoch 118/500
# 1/1 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0120 - val_mse: 0.0120 - 278ms/epoch - 278ms/step
# Epoch 119/500
# 1/1 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0142 - val_mse: 0.0142 - 278ms/epoch - 278ms/step
# Epoch 120/500
# 1/1 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0110 - val_mse: 0.0110 - 279ms/epoch - 279ms/step
# Epoch 121/500
# 1/1 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0141 - val_mse: 0.0141 - 279ms/epoch - 279ms/step
# Epoch 122/500
# 1/1 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0148 - val_mse: 0.0148 - 280ms/epoch - 280ms/step
# Epoch 123/500
# 1/1 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0137 - val_mse: 0.0137 - 280ms/epoch - 280ms/step
# Epoch 124/500
# 1/1 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0146 - val_mse: 0.0146 - 279ms/epoch - 279ms/step
# Epoch 125/500
# 1/1 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0121 - val_mse: 0.0121 - 278ms/epoch - 278ms/step
# Epoch 126/500
# 1/1 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0126 - val_mse: 0.0126 - 279ms/epoch - 279ms/step
# Epoch 127/500
# 1/1 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0137 - val_mse: 0.0137 - 277ms/epoch - 277ms/step
# Epoch 128/500
# 1/1 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0128 - val_mse: 0.0128 - 280ms/epoch - 280ms/step
# Epoch 129/500
# 1/1 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0125 - val_mse: 0.0125 - 277ms/epoch - 277ms/step
# Epoch 130/500
# 1/1 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0118 - val_mse: 0.0118 - 278ms/epoch - 278ms/step
# Epoch 131/500
# 1/1 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0125 - val_mse: 0.0125 - 279ms/epoch - 279ms/step
# Epoch 132/500
# 1/1 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0114 - val_mse: 0.0114 - 278ms/epoch - 278ms/step
# Epoch 133/500
# 1/1 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0106 - val_mse: 0.0106 - 278ms/epoch - 278ms/step
# Epoch 134/500
# 1/1 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0103 - val_mse: 0.0103 - 278ms/epoch - 278ms/step
# Epoch 135/500
# 1/1 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0097 - val_mse: 0.0097 - 278ms/epoch - 278ms/step
# Epoch 136/500
# 1/1 - 0s - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0098 - val_mse: 0.0098 - 279ms/epoch - 279ms/step
# Epoch 137/500
# 1/1 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0089 - val_mse: 0.0089 - 278ms/epoch - 278ms/step
# Epoch 138/500
# 1/1 - 0s - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0093 - val_mse: 0.0093 - 279ms/epoch - 279ms/step
# Epoch 139/500
# 1/1 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0089 - val_mse: 0.0089 - 278ms/epoch - 278ms/step
# Epoch 140/500
# 1/1 - 0s - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0098 - val_mse: 0.0098 - 278ms/epoch - 278ms/step
# Epoch 141/500
# 1/1 - 0s - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0090 - val_mse: 0.0090 - 280ms/epoch - 280ms/step
# Epoch 142/500
# 1/1 - 0s - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0091 - val_mse: 0.0091 - 281ms/epoch - 281ms/step
# Epoch 143/500
# 1/1 - 0s - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0095 - val_mse: 0.0095 - 277ms/epoch - 277ms/step
# Epoch 144/500
# 1/1 - 0s - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0094 - val_mse: 0.0094 - 278ms/epoch - 278ms/step
# Epoch 145/500
# 1/1 - 0s - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0092 - val_mse: 0.0092 - 278ms/epoch - 278ms/step
# Epoch 146/500
# 1/1 - 0s - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0090 - val_mse: 0.0090 - 279ms/epoch - 279ms/step
# Epoch 147/500
# 1/1 - 0s - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0094 - val_mse: 0.0094 - 279ms/epoch - 279ms/step
# Epoch 148/500
# 1/1 - 0s - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0090 - val_mse: 0.0090 - 280ms/epoch - 280ms/step
# Epoch 149/500
# 1/1 - 0s - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0088 - val_mse: 0.0088 - 278ms/epoch - 278ms/step
# Epoch 150/500
# 1/1 - 0s - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0086 - val_mse: 0.0086 - 279ms/epoch - 279ms/step
# Epoch 151/500
# 1/1 - 0s - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0084 - val_mse: 0.0084 - 279ms/epoch - 279ms/step
# Epoch 152/500
# 1/1 - 0s - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0081 - val_mse: 0.0081 - 278ms/epoch - 278ms/step
# Epoch 153/500
# 1/1 - 0s - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0081 - val_mse: 0.0081 - 278ms/epoch - 278ms/step
# Epoch 154/500
# 1/1 - 0s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0083 - val_mse: 0.0083 - 281ms/epoch - 281ms/step
# Epoch 155/500
# 1/1 - 0s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0081 - val_mse: 0.0081 - 278ms/epoch - 278ms/step
# Epoch 156/500
# 1/1 - 0s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0080 - val_mse: 0.0080 - 278ms/epoch - 278ms/step
# Epoch 157/500
# 1/1 - 0s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0081 - val_mse: 0.0081 - 278ms/epoch - 278ms/step
# Epoch 158/500
# 1/1 - 0s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0078 - val_mse: 0.0078 - 279ms/epoch - 279ms/step
# Epoch 159/500
# 1/1 - 0s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0078 - val_mse: 0.0078 - 279ms/epoch - 279ms/step
# Epoch 160/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0080 - val_mse: 0.0080 - 278ms/epoch - 278ms/step
# Epoch 161/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0080 - val_mse: 0.0080 - 278ms/epoch - 278ms/step
# Epoch 162/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0080 - val_mse: 0.0080 - 279ms/epoch - 279ms/step
# Epoch 163/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0079 - val_mse: 0.0079 - 281ms/epoch - 281ms/step
# Epoch 164/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0076 - val_mse: 0.0076 - 280ms/epoch - 280ms/step
# Epoch 165/500
# 1/1 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0074 - val_mse: 0.0074 - 279ms/epoch - 279ms/step
# Epoch 166/500
# 1/1 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0074 - val_mse: 0.0074 - 279ms/epoch - 279ms/step
# Epoch 167/500
# 1/1 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0072 - val_mse: 0.0072 - 279ms/epoch - 279ms/step
# Epoch 168/500
# 1/1 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0072 - val_mse: 0.0072 - 278ms/epoch - 278ms/step
# Epoch 169/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0071 - val_mse: 0.0071 - 278ms/epoch - 278ms/step
# Epoch 170/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0069 - val_mse: 0.0069 - 278ms/epoch - 278ms/step
# Epoch 171/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0069 - val_mse: 0.0069 - 279ms/epoch - 279ms/step
# Epoch 172/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0067 - val_mse: 0.0067 - 279ms/epoch - 279ms/step
# Epoch 173/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0068 - val_mse: 0.0068 - 278ms/epoch - 278ms/step
# Epoch 174/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0068 - val_mse: 0.0068 - 278ms/epoch - 278ms/step
# Epoch 175/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0068 - val_mse: 0.0068 - 279ms/epoch - 279ms/step
# Epoch 176/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0068 - val_mse: 0.0068 - 279ms/epoch - 279ms/step
# Epoch 177/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0066 - val_mse: 0.0066 - 278ms/epoch - 278ms/step
# Epoch 178/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0066 - val_mse: 0.0066 - 278ms/epoch - 278ms/step
# Epoch 179/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0064 - val_mse: 0.0064 - 278ms/epoch - 278ms/step
# Epoch 180/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0066 - val_mse: 0.0066 - 280ms/epoch - 280ms/step
# Epoch 181/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0063 - val_mse: 0.0063 - 279ms/epoch - 279ms/step
# Epoch 182/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0067 - val_mse: 0.0067 - 278ms/epoch - 278ms/step
# Epoch 183/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0063 - val_mse: 0.0063 - 278ms/epoch - 278ms/step
# Epoch 184/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0072 - val_mse: 0.0072 - 280ms/epoch - 280ms/step
# Epoch 185/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0067 - val_mse: 0.0067 - 276ms/epoch - 276ms/step
# Epoch 186/500
# 1/1 - 0s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0086 - val_mse: 0.0086 - 279ms/epoch - 279ms/step
# Epoch 187/500
# 1/1 - 0s - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0070 - val_mse: 0.0070 - 279ms/epoch - 279ms/step
# Epoch 188/500
# 1/1 - 0s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0072 - val_mse: 0.0072 - 279ms/epoch - 279ms/step
# Epoch 189/500
# 1/1 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0069 - val_mse: 0.0069 - 277ms/epoch - 277ms/step
# Epoch 190/500
# 1/1 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0068 - val_mse: 0.0068 - 279ms/epoch - 279ms/step
# Epoch 191/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0078 - val_mse: 0.0078 - 277ms/epoch - 277ms/step
# Epoch 192/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0066 - val_mse: 0.0066 - 277ms/epoch - 277ms/step
# Epoch 193/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0066 - val_mse: 0.0066 - 280ms/epoch - 280ms/step
# Epoch 194/500
# 1/1 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0077 - val_mse: 0.0077 - 279ms/epoch - 279ms/step
# Epoch 195/500
# 1/1 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0065 - val_mse: 0.0065 - 278ms/epoch - 278ms/step
# Epoch 196/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0064 - val_mse: 0.0064 - 280ms/epoch - 280ms/step
# Epoch 197/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0073 - val_mse: 0.0073 - 280ms/epoch - 280ms/step
# Epoch 198/500
# 1/1 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0064 - val_mse: 0.0064 - 279ms/epoch - 279ms/step
# Epoch 199/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0065 - val_mse: 0.0065 - 279ms/epoch - 279ms/step
# Epoch 200/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0071 - val_mse: 0.0071 - 279ms/epoch - 279ms/step
# Epoch 201/500
# 1/1 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0065 - val_mse: 0.0065 - 278ms/epoch - 278ms/step
# Epoch 202/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0065 - val_mse: 0.0065 - 278ms/epoch - 278ms/step
# Epoch 203/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0068 - val_mse: 0.0068 - 278ms/epoch - 278ms/step
# Epoch 204/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0063 - val_mse: 0.0063 - 280ms/epoch - 280ms/step
# Epoch 205/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0063 - val_mse: 0.0063 - 279ms/epoch - 279ms/step
# Epoch 206/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0064 - val_mse: 0.0064 - 279ms/epoch - 279ms/step
# Epoch 207/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0061 - val_mse: 0.0061 - 279ms/epoch - 279ms/step
# Epoch 208/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0062 - val_mse: 0.0062 - 278ms/epoch - 278ms/step
# Epoch 209/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0060 - val_mse: 0.0060 - 280ms/epoch - 280ms/step
# Epoch 210/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0060 - val_mse: 0.0060 - 278ms/epoch - 278ms/step
# Epoch 211/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0061 - val_mse: 0.0061 - 279ms/epoch - 279ms/step
# Epoch 212/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0059 - val_mse: 0.0059 - 278ms/epoch - 278ms/step
# Epoch 213/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0060 - val_mse: 0.0060 - 278ms/epoch - 278ms/step
# Epoch 214/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0060 - val_mse: 0.0060 - 279ms/epoch - 279ms/step
# Epoch 215/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0059 - val_mse: 0.0059 - 280ms/epoch - 280ms/step
# Epoch 216/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0060 - val_mse: 0.0060 - 279ms/epoch - 279ms/step
# Epoch 217/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0058 - val_mse: 0.0058 - 278ms/epoch - 278ms/step
# Epoch 218/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0058 - val_mse: 0.0058 - 279ms/epoch - 279ms/step
# Epoch 219/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 220/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 276ms/epoch - 276ms/step
# Epoch 221/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 222/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0056 - val_mse: 0.0056 - 279ms/epoch - 279ms/step
# Epoch 223/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 224/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0056 - val_mse: 0.0056 - 279ms/epoch - 279ms/step
# Epoch 225/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 226/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0056 - val_mse: 0.0056 - 279ms/epoch - 279ms/step
# Epoch 227/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 280ms/epoch - 280ms/step
# Epoch 228/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0055 - val_mse: 0.0055 - 279ms/epoch - 279ms/step
# Epoch 229/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 230/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0055 - val_mse: 0.0055 - 278ms/epoch - 278ms/step
# Epoch 231/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0058 - val_mse: 0.0058 - 277ms/epoch - 277ms/step
# Epoch 232/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0056 - val_mse: 0.0056 - 279ms/epoch - 279ms/step
# Epoch 233/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0061 - val_mse: 0.0061 - 278ms/epoch - 278ms/step
# Epoch 234/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0058 - val_mse: 0.0058 - 279ms/epoch - 279ms/step
# Epoch 235/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0065 - val_mse: 0.0065 - 280ms/epoch - 280ms/step
# Epoch 236/500
# 1/1 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0059 - val_mse: 0.0059 - 280ms/epoch - 280ms/step
# Epoch 237/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0064 - val_mse: 0.0064 - 279ms/epoch - 279ms/step
# Epoch 238/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 239/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057 - 279ms/epoch - 279ms/step
# Epoch 240/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0058 - val_mse: 0.0058 - 280ms/epoch - 280ms/step
# Epoch 241/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0056 - val_mse: 0.0056 - 278ms/epoch - 278ms/step
# Epoch 242/500
# 1/1 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0060 - val_mse: 0.0060 - 280ms/epoch - 280ms/step
# Epoch 243/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0055 - val_mse: 0.0055 - 279ms/epoch - 279ms/step
# Epoch 244/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0055 - val_mse: 0.0055 - 277ms/epoch - 277ms/step
# Epoch 245/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0055 - val_mse: 0.0055 - 281ms/epoch - 281ms/step
# Epoch 246/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 278ms/epoch - 278ms/step
# Epoch 247/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0058 - val_mse: 0.0058 - 278ms/epoch - 278ms/step
# Epoch 248/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0055 - val_mse: 0.0055 - 278ms/epoch - 278ms/step
# Epoch 249/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0056 - val_mse: 0.0056 - 279ms/epoch - 279ms/step
# Epoch 250/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 278ms/epoch - 278ms/step
# Epoch 251/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 279ms/epoch - 279ms/step
# Epoch 252/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0055 - val_mse: 0.0055 - 279ms/epoch - 279ms/step
# Epoch 253/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0053 - val_mse: 0.0053 - 280ms/epoch - 280ms/step
# Epoch 254/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0055 - val_mse: 0.0055 - 279ms/epoch - 279ms/step
# Epoch 255/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053 - 277ms/epoch - 277ms/step
# Epoch 256/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 279ms/epoch - 279ms/step
# Epoch 257/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0053 - val_mse: 0.0053 - 280ms/epoch - 280ms/step
# Epoch 258/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0053 - val_mse: 0.0053 - 279ms/epoch - 279ms/step
# Epoch 259/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0052 - val_mse: 0.0052 - 279ms/epoch - 279ms/step
# Epoch 260/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0052 - val_mse: 0.0052 - 280ms/epoch - 280ms/step
# Epoch 261/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0052 - val_mse: 0.0052 - 278ms/epoch - 278ms/step
# Epoch 262/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 263/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0052 - val_mse: 0.0052 - 278ms/epoch - 278ms/step
# Epoch 264/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0051 - val_mse: 0.0051 - 278ms/epoch - 278ms/step
# Epoch 265/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 278ms/epoch - 278ms/step
# Epoch 266/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0053 - val_mse: 0.0053 - 281ms/epoch - 281ms/step
# Epoch 267/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0060 - val_mse: 0.0060 - 278ms/epoch - 278ms/step
# Epoch 268/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0059 - val_mse: 0.0059 - 279ms/epoch - 279ms/step
# Epoch 269/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0070 - val_mse: 0.0070 - 278ms/epoch - 278ms/step
# Epoch 270/500
# 1/1 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0060 - val_mse: 0.0060 - 279ms/epoch - 279ms/step
# Epoch 271/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0060 - val_mse: 0.0060 - 279ms/epoch - 279ms/step
# Epoch 272/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0055 - val_mse: 0.0055 - 278ms/epoch - 278ms/step
# Epoch 273/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0055 - val_mse: 0.0055 - 279ms/epoch - 279ms/step
# Epoch 274/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0062 - val_mse: 0.0062 - 279ms/epoch - 279ms/step
# Epoch 275/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0054 - val_mse: 0.0054 - 280ms/epoch - 280ms/step
# Epoch 276/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053 - 278ms/epoch - 278ms/step
# Epoch 277/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0054 - val_mse: 0.0054 - 279ms/epoch - 279ms/step
# Epoch 278/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0054 - val_mse: 0.0054 - 280ms/epoch - 280ms/step
# Epoch 279/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0057 - val_mse: 0.0057 - 278ms/epoch - 278ms/step
# Epoch 280/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053 - 279ms/epoch - 279ms/step
# Epoch 281/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0054 - val_mse: 0.0054 - 278ms/epoch - 278ms/step
# Epoch 282/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0057 - val_mse: 0.0057 - 279ms/epoch - 279ms/step
# Epoch 283/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 279ms/epoch - 279ms/step
# Epoch 284/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0053 - val_mse: 0.0053 - 279ms/epoch - 279ms/step
# Epoch 285/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0052 - val_mse: 0.0052 - 279ms/epoch - 279ms/step
# Epoch 286/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0052 - val_mse: 0.0052 - 279ms/epoch - 279ms/step
# Epoch 287/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0053 - val_mse: 0.0053 - 278ms/epoch - 278ms/step
# Epoch 288/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 289/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0051 - val_mse: 0.0051 - 280ms/epoch - 280ms/step
# Epoch 290/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 291/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0051 - val_mse: 0.0051 - 278ms/epoch - 278ms/step
# Epoch 292/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0052 - val_mse: 0.0052 - 278ms/epoch - 278ms/step
# Epoch 293/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0051 - val_mse: 0.0051 - 280ms/epoch - 280ms/step
# Epoch 294/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0051 - val_mse: 0.0051 - 280ms/epoch - 280ms/step
# Epoch 295/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 296/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 297/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 280ms/epoch - 280ms/step
# Epoch 298/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 299/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 278ms/epoch - 278ms/step
# Epoch 300/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0049 - val_mse: 0.0049 - 280ms/epoch - 280ms/step
# Epoch 301/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 278ms/epoch - 278ms/step
# Epoch 302/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 303/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 304/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 280ms/epoch - 280ms/step
# Epoch 305/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 306/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 280ms/epoch - 280ms/step
# Epoch 307/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 308/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 309/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 310/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 311/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 312/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0055 - val_mse: 0.0055 - 279ms/epoch - 279ms/step
# Epoch 313/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0053 - val_mse: 0.0053 - 278ms/epoch - 278ms/step
# Epoch 314/500
# 1/1 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0058 - val_mse: 0.0058 - 278ms/epoch - 278ms/step
# Epoch 315/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0053 - val_mse: 0.0053 - 279ms/epoch - 279ms/step
# Epoch 316/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054 - 278ms/epoch - 278ms/step
# Epoch 317/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0050 - val_mse: 0.0050 - 277ms/epoch - 277ms/step
# Epoch 318/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 280ms/epoch - 280ms/step
# Epoch 319/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 320/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 321/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0052 - val_mse: 0.0052 - 280ms/epoch - 280ms/step
# Epoch 322/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0049 - val_mse: 0.0049 - 277ms/epoch - 277ms/step
# Epoch 323/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 324/500
# 1/1 - 0s - loss: 9.6062e-04 - mse: 9.6062e-04 - val_loss: 0.0050 - val_mse: 0.0050 - 278ms/epoch - 278ms/step
# Epoch 325/500
# 1/1 - 0s - loss: 9.8559e-04 - mse: 9.8559e-04 - val_loss: 0.0050 - val_mse: 0.0050 - 278ms/epoch - 278ms/step
# Epoch 326/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0052 - val_mse: 0.0052 - 279ms/epoch - 279ms/step
# Epoch 327/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 280ms/epoch - 280ms/step
# Epoch 328/500
# 1/1 - 0s - loss: 9.9974e-04 - mse: 9.9974e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 329/500
# 1/1 - 0s - loss: 9.4720e-04 - mse: 9.4720e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 277ms/epoch - 277ms/step
# Epoch 330/500
# 1/1 - 0s - loss: 9.4194e-04 - mse: 9.4194e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 331/500
# 1/1 - 0s - loss: 9.7522e-04 - mse: 9.7522e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 332/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 333/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 334/500
# 1/1 - 0s - loss: 9.9587e-04 - mse: 9.9587e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 335/500
# 1/1 - 0s - loss: 9.5303e-04 - mse: 9.5303e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 336/500
# 1/1 - 0s - loss: 9.2333e-04 - mse: 9.2333e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 280ms/epoch - 280ms/step
# Epoch 337/500
# 1/1 - 0s - loss: 9.1245e-04 - mse: 9.1245e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 280ms/epoch - 280ms/step
# Epoch 338/500
# 1/1 - 0s - loss: 9.1890e-04 - mse: 9.1890e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 277ms/epoch - 277ms/step
# Epoch 339/500
# 1/1 - 0s - loss: 9.3536e-04 - mse: 9.3536e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 279ms/epoch - 279ms/step
# Epoch 340/500
# 1/1 - 0s - loss: 9.5113e-04 - mse: 9.5113e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 280ms/epoch - 280ms/step
# Epoch 341/500
# 1/1 - 0s - loss: 9.7452e-04 - mse: 9.7452e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 342/500
# 1/1 - 0s - loss: 9.8275e-04 - mse: 9.8275e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 343/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0048 - val_mse: 0.0048 - 279ms/epoch - 279ms/step
# Epoch 344/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0050 - val_mse: 0.0050 - 280ms/epoch - 280ms/step
# Epoch 345/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 346/500
# 1/1 - 0s - loss: 9.9547e-04 - mse: 9.9547e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 347/500
# 1/1 - 0s - loss: 9.7769e-04 - mse: 9.7769e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 279ms/epoch - 279ms/step
# Epoch 348/500
# 1/1 - 0s - loss: 9.3617e-04 - mse: 9.3617e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 280ms/epoch - 280ms/step
# Epoch 349/500
# 1/1 - 0s - loss: 9.0871e-04 - mse: 9.0871e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 350/500
# 1/1 - 0s - loss: 8.8648e-04 - mse: 8.8648e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 281ms/epoch - 281ms/step
# Epoch 351/500
# 1/1 - 0s - loss: 8.7408e-04 - mse: 8.7408e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 352/500
# 1/1 - 0s - loss: 8.6776e-04 - mse: 8.6776e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 353/500
# 1/1 - 0s - loss: 8.6625e-04 - mse: 8.6625e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 280ms/epoch - 280ms/step
# Epoch 354/500
# 1/1 - 0s - loss: 8.6901e-04 - mse: 8.6901e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 355/500
# 1/1 - 0s - loss: 8.7573e-04 - mse: 8.7573e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 279ms/epoch - 279ms/step
# Epoch 356/500
# 1/1 - 0s - loss: 8.9034e-04 - mse: 8.9034e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 357/500
# 1/1 - 0s - loss: 9.1152e-04 - mse: 9.1152e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 280ms/epoch - 280ms/step
# Epoch 358/500
# 1/1 - 0s - loss: 9.6299e-04 - mse: 9.6299e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 277ms/epoch - 277ms/step
# Epoch 359/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 360/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0052 - val_mse: 0.0052 - 279ms/epoch - 279ms/step
# Epoch 361/500
# 1/1 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0061 - val_mse: 0.0061 - 279ms/epoch - 279ms/step
# Epoch 362/500
# 1/1 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0057 - val_mse: 0.0057 - 279ms/epoch - 279ms/step
# Epoch 363/500
# 1/1 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0062 - val_mse: 0.0062 - 279ms/epoch - 279ms/step
# Epoch 364/500
# 1/1 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0052 - val_mse: 0.0052 - 279ms/epoch - 279ms/step
# Epoch 365/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 366/500
# 1/1 - 0s - loss: 8.6881e-04 - mse: 8.6881e-04 - val_loss: 0.0053 - val_mse: 0.0053 - 280ms/epoch - 280ms/step
# Epoch 367/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 368/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0053 - val_mse: 0.0053 - 279ms/epoch - 279ms/step
# Epoch 369/500
# 1/1 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0048 - val_mse: 0.0048 - 279ms/epoch - 279ms/step
# Epoch 370/500
# 1/1 - 0s - loss: 8.8354e-04 - mse: 8.8354e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 371/500
# 1/1 - 0s - loss: 9.1088e-04 - mse: 9.1088e-04 - val_loss: 0.0053 - val_mse: 0.0053 - 279ms/epoch - 279ms/step
# Epoch 372/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0050 - val_mse: 0.0050 - 278ms/epoch - 278ms/step
# Epoch 373/500
# 1/1 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 374/500
# 1/1 - 0s - loss: 8.5849e-04 - mse: 8.5849e-04 - val_loss: 0.0050 - val_mse: 0.0050 - 279ms/epoch - 279ms/step
# Epoch 375/500
# 1/1 - 0s - loss: 8.7291e-04 - mse: 8.7291e-04 - val_loss: 0.0051 - val_mse: 0.0051 - 279ms/epoch - 279ms/step
# Epoch 376/500
# 1/1 - 0s - loss: 9.6373e-04 - mse: 9.6373e-04 - val_loss: 0.0050 - val_mse: 0.0050 - 278ms/epoch - 278ms/step
# Epoch 377/500
# 1/1 - 0s - loss: 9.5380e-04 - mse: 9.5380e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 277ms/epoch - 277ms/step
# Epoch 378/500
# 1/1 - 0s - loss: 8.4243e-04 - mse: 8.4243e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 379/500
# 1/1 - 0s - loss: 8.4076e-04 - mse: 8.4076e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 380/500
# 1/1 - 0s - loss: 9.1803e-04 - mse: 9.1803e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 381/500
# 1/1 - 0s - loss: 9.0934e-04 - mse: 9.0934e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 279ms/epoch - 279ms/step
# Epoch 382/500
# 1/1 - 0s - loss: 8.4722e-04 - mse: 8.4722e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 279ms/epoch - 279ms/step
# Epoch 383/500
# 1/1 - 0s - loss: 8.0923e-04 - mse: 8.0923e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 280ms/epoch - 280ms/step
# Epoch 384/500
# 1/1 - 0s - loss: 8.4298e-04 - mse: 8.4298e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 385/500
# 1/1 - 0s - loss: 8.7994e-04 - mse: 8.7994e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 386/500
# 1/1 - 0s - loss: 8.4677e-04 - mse: 8.4677e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 387/500
# 1/1 - 0s - loss: 8.0463e-04 - mse: 8.0463e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 388/500
# 1/1 - 0s - loss: 7.9771e-04 - mse: 7.9771e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 279ms/epoch - 279ms/step
# Epoch 389/500
# 1/1 - 0s - loss: 8.2288e-04 - mse: 8.2288e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 390/500
# 1/1 - 0s - loss: 8.4623e-04 - mse: 8.4623e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 280ms/epoch - 280ms/step
# Epoch 391/500
# 1/1 - 0s - loss: 8.3182e-04 - mse: 8.3182e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 392/500
# 1/1 - 0s - loss: 8.0558e-04 - mse: 8.0558e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 280ms/epoch - 280ms/step
# Epoch 393/500
# 1/1 - 0s - loss: 7.8388e-04 - mse: 7.8388e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 394/500
# 1/1 - 0s - loss: 7.8312e-04 - mse: 7.8312e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 279ms/epoch - 279ms/step
# Epoch 395/500
# 1/1 - 0s - loss: 7.9658e-04 - mse: 7.9658e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 396/500
# 1/1 - 0s - loss: 8.0753e-04 - mse: 8.0753e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 397/500
# 1/1 - 0s - loss: 8.1232e-04 - mse: 8.1232e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 398/500
# 1/1 - 0s - loss: 8.0132e-04 - mse: 8.0132e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 399/500
# 1/1 - 0s - loss: 7.8886e-04 - mse: 7.8886e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 400/500
# 1/1 - 0s - loss: 7.7423e-04 - mse: 7.7423e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 401/500
# 1/1 - 0s - loss: 7.6457e-04 - mse: 7.6457e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 402/500
# 1/1 - 0s - loss: 7.6047e-04 - mse: 7.6047e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 403/500
# 1/1 - 0s - loss: 7.6086e-04 - mse: 7.6086e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 404/500
# 1/1 - 0s - loss: 7.6388e-04 - mse: 7.6388e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 405/500
# 1/1 - 0s - loss: 7.6758e-04 - mse: 7.6758e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 406/500
# 1/1 - 0s - loss: 7.7249e-04 - mse: 7.7249e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 407/500
# 1/1 - 0s - loss: 7.7550e-04 - mse: 7.7550e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 408/500
# 1/1 - 0s - loss: 7.8228e-04 - mse: 7.8228e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 409/500
# 1/1 - 0s - loss: 7.8643e-04 - mse: 7.8643e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 280ms/epoch - 280ms/step
# Epoch 410/500
# 1/1 - 0s - loss: 7.9857e-04 - mse: 7.9857e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 411/500
# 1/1 - 0s - loss: 8.0492e-04 - mse: 8.0492e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 412/500
# 1/1 - 0s - loss: 8.2403e-04 - mse: 8.2403e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 413/500
# 1/1 - 0s - loss: 8.2847e-04 - mse: 8.2847e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 414/500
# 1/1 - 0s - loss: 8.5120e-04 - mse: 8.5120e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 415/500
# 1/1 - 0s - loss: 8.4973e-04 - mse: 8.4973e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 277ms/epoch - 277ms/step
# Epoch 416/500
# 1/1 - 0s - loss: 8.7293e-04 - mse: 8.7293e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 417/500
# 1/1 - 0s - loss: 8.6048e-04 - mse: 8.6048e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 418/500
# 1/1 - 0s - loss: 8.7096e-04 - mse: 8.7096e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 419/500
# 1/1 - 0s - loss: 8.4069e-04 - mse: 8.4069e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 279ms/epoch - 279ms/step
# Epoch 420/500
# 1/1 - 0s - loss: 8.2491e-04 - mse: 8.2491e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 421/500
# 1/1 - 0s - loss: 7.8610e-04 - mse: 7.8610e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 422/500
# 1/1 - 0s - loss: 7.5894e-04 - mse: 7.5894e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 423/500
# 1/1 - 0s - loss: 7.3523e-04 - mse: 7.3523e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 424/500
# 1/1 - 0s - loss: 7.2245e-04 - mse: 7.2245e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 425/500
# 1/1 - 0s - loss: 7.1837e-04 - mse: 7.1837e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 426/500
# 1/1 - 0s - loss: 7.2089e-04 - mse: 7.2089e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 280ms/epoch - 280ms/step
# Epoch 427/500
# 1/1 - 0s - loss: 7.2829e-04 - mse: 7.2829e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 276ms/epoch - 276ms/step
# Epoch 428/500
# 1/1 - 0s - loss: 7.3795e-04 - mse: 7.3795e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 429/500
# 1/1 - 0s - loss: 7.5340e-04 - mse: 7.5340e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 430/500
# 1/1 - 0s - loss: 7.6710e-04 - mse: 7.6710e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 431/500
# 1/1 - 0s - loss: 7.9407e-04 - mse: 7.9407e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 432/500
# 1/1 - 0s - loss: 8.1288e-04 - mse: 8.1288e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 277ms/epoch - 277ms/step
# Epoch 433/500
# 1/1 - 0s - loss: 8.6344e-04 - mse: 8.6344e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 276ms/epoch - 276ms/step
# Epoch 434/500
# 1/1 - 0s - loss: 8.8747e-04 - mse: 8.8747e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 278ms/epoch - 278ms/step
# Epoch 435/500
# 1/1 - 0s - loss: 9.7261e-04 - mse: 9.7261e-04 - val_loss: 0.0048 - val_mse: 0.0048 - 278ms/epoch - 278ms/step
# Epoch 436/500
# 1/1 - 0s - loss: 9.7916e-04 - mse: 9.7916e-04 - val_loss: 0.0051 - val_mse: 0.0051 - 278ms/epoch - 278ms/step
# Epoch 437/500
# 1/1 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0049 - val_mse: 0.0049 - 281ms/epoch - 281ms/step
# Epoch 438/500
# 1/1 - 0s - loss: 9.7403e-04 - mse: 9.7403e-04 - val_loss: 0.0049 - val_mse: 0.0049 - 279ms/epoch - 279ms/step
# Epoch 439/500
# 1/1 - 0s - loss: 9.2120e-04 - mse: 9.2120e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 440/500
# 1/1 - 0s - loss: 7.8854e-04 - mse: 7.8854e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 441/500
# 1/1 - 0s - loss: 7.1092e-04 - mse: 7.1092e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 442/500
# 1/1 - 0s - loss: 7.0130e-04 - mse: 7.0130e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 443/500
# 1/1 - 0s - loss: 7.4784e-04 - mse: 7.4784e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 444/500
# 1/1 - 0s - loss: 8.1443e-04 - mse: 8.1443e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 276ms/epoch - 276ms/step
# Epoch 445/500
# 1/1 - 0s - loss: 8.2784e-04 - mse: 8.2784e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 278ms/epoch - 278ms/step
# Epoch 446/500
# 1/1 - 0s - loss: 8.2619e-04 - mse: 8.2619e-04 - val_loss: 0.0047 - val_mse: 0.0047 - 277ms/epoch - 277ms/step
# Epoch 447/500
# 1/1 - 0s - loss: 7.6305e-04 - mse: 7.6305e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 448/500
# 1/1 - 0s - loss: 7.1158e-04 - mse: 7.1158e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 449/500
# 1/1 - 0s - loss: 6.8504e-04 - mse: 6.8504e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 450/500
# 1/1 - 0s - loss: 6.9408e-04 - mse: 6.9408e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 451/500
# 1/1 - 0s - loss: 7.2461e-04 - mse: 7.2461e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 452/500
# 1/1 - 0s - loss: 7.4793e-04 - mse: 7.4793e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 453/500
# 1/1 - 0s - loss: 7.6732e-04 - mse: 7.6732e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 276ms/epoch - 276ms/step
# Epoch 454/500
# 1/1 - 0s - loss: 7.5254e-04 - mse: 7.5254e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 455/500
# 1/1 - 0s - loss: 7.3648e-04 - mse: 7.3648e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 456/500
# 1/1 - 0s - loss: 7.0515e-04 - mse: 7.0515e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 457/500
# 1/1 - 0s - loss: 6.8173e-04 - mse: 6.8173e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 458/500
# 1/1 - 0s - loss: 6.6948e-04 - mse: 6.6948e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 459/500
# 1/1 - 0s - loss: 6.7049e-04 - mse: 6.7049e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 279ms/epoch - 279ms/step
# Epoch 460/500
# 1/1 - 0s - loss: 6.8073e-04 - mse: 6.8073e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 278ms/epoch - 278ms/step
# Epoch 461/500
# 1/1 - 0s - loss: 6.9363e-04 - mse: 6.9363e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 278ms/epoch - 278ms/step
# Epoch 462/500
# 1/1 - 0s - loss: 7.1101e-04 - mse: 7.1101e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 463/500
# 1/1 - 0s - loss: 7.2376e-04 - mse: 7.2376e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 464/500
# 1/1 - 0s - loss: 7.4913e-04 - mse: 7.4913e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 465/500
# 1/1 - 0s - loss: 7.6036e-04 - mse: 7.6036e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 466/500
# 1/1 - 0s - loss: 7.8930e-04 - mse: 7.8930e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 467/500
# 1/1 - 0s - loss: 7.8593e-04 - mse: 7.8593e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 468/500
# 1/1 - 0s - loss: 8.0429e-04 - mse: 8.0429e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 469/500
# 1/1 - 0s - loss: 7.8365e-04 - mse: 7.8365e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 470/500
# 1/1 - 0s - loss: 7.8389e-04 - mse: 7.8389e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 279ms/epoch - 279ms/step
# Epoch 471/500
# 1/1 - 0s - loss: 7.4679e-04 - mse: 7.4679e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 472/500
# 1/1 - 0s - loss: 7.1972e-04 - mse: 7.1972e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 473/500
# 1/1 - 0s - loss: 6.8113e-04 - mse: 6.8113e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 276ms/epoch - 276ms/step
# Epoch 474/500
# 1/1 - 0s - loss: 6.5575e-04 - mse: 6.5575e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 279ms/epoch - 279ms/step
# Epoch 475/500
# 1/1 - 0s - loss: 6.4558e-04 - mse: 6.4558e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 279ms/epoch - 279ms/step
# Epoch 476/500
# 1/1 - 0s - loss: 6.5066e-04 - mse: 6.5066e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 280ms/epoch - 280ms/step
# Epoch 477/500
# 1/1 - 0s - loss: 6.6577e-04 - mse: 6.6577e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 478/500
# 1/1 - 0s - loss: 6.8239e-04 - mse: 6.8239e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 479/500
# 1/1 - 0s - loss: 7.0419e-04 - mse: 7.0419e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 480/500
# 1/1 - 0s - loss: 7.1436e-04 - mse: 7.1436e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 279ms/epoch - 279ms/step
# Epoch 481/500
# 1/1 - 0s - loss: 7.3425e-04 - mse: 7.3425e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 482/500
# 1/1 - 0s - loss: 7.3344e-04 - mse: 7.3344e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 483/500
# 1/1 - 0s - loss: 7.4562e-04 - mse: 7.4562e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 277ms/epoch - 277ms/step
# Epoch 484/500
# 1/1 - 0s - loss: 7.3175e-04 - mse: 7.3175e-04 - val_loss: 0.0046 - val_mse: 0.0046 - 278ms/epoch - 278ms/step
# Epoch 485/500
# 1/1 - 0s - loss: 7.2987e-04 - mse: 7.2987e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 277ms/epoch - 277ms/step
# Epoch 486/500
# 1/1 - 0s - loss: 7.0657e-04 - mse: 7.0657e-04 - val_loss: 0.0045 - val_mse: 0.0045 - 278ms/epoch - 278ms/step
# Epoch 487/500
# 1/1 - 0s - loss: 6.9274e-04 - mse: 6.9274e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step
# Epoch 488/500
# 1/1 - 0s - loss: 6.7002e-04 - mse: 6.7002e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 278ms/epoch - 278ms/step
# Epoch 489/500
# 1/1 - 0s - loss: 6.5486e-04 - mse: 6.5486e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 280ms/epoch - 280ms/step
# Epoch 490/500
# 1/1 - 0s - loss: 6.4099e-04 - mse: 6.4099e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step
# Epoch 491/500
# 1/1 - 0s - loss: 6.3220e-04 - mse: 6.3220e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step
# Epoch 492/500
# 1/1 - 0s - loss: 6.2622e-04 - mse: 6.2622e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 279ms/epoch - 279ms/step
# Epoch 493/500
# 1/1 - 0s - loss: 6.2263e-04 - mse: 6.2263e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 280ms/epoch - 280ms/step
# Epoch 494/500
# 1/1 - 0s - loss: 6.2049e-04 - mse: 6.2049e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 278ms/epoch - 278ms/step
# Epoch 495/500
# 1/1 - 0s - loss: 6.1941e-04 - mse: 6.1941e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step
# Epoch 496/500
# 1/1 - 0s - loss: 6.1942e-04 - mse: 6.1942e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 278ms/epoch - 278ms/step
# Epoch 497/500
# 1/1 - 0s - loss: 6.2047e-04 - mse: 6.2047e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 279ms/epoch - 279ms/step
# Epoch 498/500
# 1/1 - 0s - loss: 6.2328e-04 - mse: 6.2328e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step
# Epoch 499/500
# 1/1 - 0s - loss: 6.2852e-04 - mse: 6.2852e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step
# Epoch 500/500
# 1/1 - 0s - loss: 6.4105e-04 - mse: 6.4105e-04 - val_loss: 0.0044 - val_mse: 0.0044 - 277ms/epoch - 277ms/step

# %% [markdown]
# ### Loading trained model and evaluation

# %%
from keras.models import load_model
saved_model = load_model('/scratch/astro/nicolo.fiaba/trained_models/unet_model_cars.h5', compile=False)

saved_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss='mse',
                  metrics="mse")
# saved_model.summary()

# %% [markdown]
# ---

# %%
pred_trained = saved_model.predict(test)
pred_trained = np.squeeze(pred_trained)
# Out:
# 1/1 [==============================] - 12s 12s/step

# %%
pred_untrained = unet_model.predict(test)
pred_untrained = np.squeeze(pred_untrained)
# Out:
# 1/1 [==============================] - 0s 158ms/step

# %%
import random
index = 2
print(index)

fig, axs = plt.subplots(1, 2, figsize=(10,5))
lis = [test, pred_untrained]
titles = ['Input', 'Output \n Trained model']

for i, ax in enumerate(axs.flatten()):
    ax.imshow(visu.normalize_image(lis[i][index], levels=(5, 95)), aspect=1)
    ax.set_title(titles[i], fontsize=9)
plt.suptitle("Index: {}".format(index))
# plt.savefig('/scratch/astro/nicolo.fiaba/ex1.png')
# Out:
# 2
# Text(0.5, 0.98, 'Index: 2')

# %% [markdown]
# Let's compute the reconstruction error for each reconstructed image

# %%
tf.reduce_mean(tf.keras.losses.MSE(
    test, pred_trained
))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.001671737>

# %%
w=0.1
error = K.square(test - pred_trained)
error = K.switch(K.less(test, tf.reduce_mean(train)), w * error, error)

# %%
tf.reduce_mean(error)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.165408e-05>

# %% [markdown]
# ### Measuring reconstruction error

# %%
mse = tf.keras.losses.MeanSquaredError(None)
# Global average error
recon_error = mse(scale_img.reshape(1548, -1), img_regenerated.reshape(1548, -1))

# %%
print(recon_error.numpy())

# %%
recon_error[769].numpy()
